# %% [markdown]
# ### (1) 도서 정보 크롤링
#
# [All products | Books to Scrape - Sandbox](https://books.toscrape.com/)
#
# - 위 사이트에서 카테고리별로 책 정보를 수집합니다.
# - 수집한 데이터는 json 파일에 저장합니다.
# - 책 정보 수집을 위해 필요한 상호작용
#     - 요소 탐색
#     - 요소 텍스트 추출
#     - 요소 속성(href) 추출
#     - 카테고리 선택 버튼 탐색 및 클릭
#     - 다음 페이지 이동 버튼 탐색 및 클릭
# - 수집할 책 카테고리
#     - Travel
#     - Romance
#     - Fiction
# - 수집할 책 정보 목록
#     - 카테고리
#     - 책 이름
#     - 책 가격
#     - 상세 정보 페이지 주소
# - `WebElement.get_attribute(속성명)`
#     - 요소의 속성명에 해당하는 속성 정보를 반환합니다.
# - json 파일 예시
#
# ```json
# [
#     {
#         "카테고리": "Travel",
#         "책 이름": "It's Only the Himalayas",
#         "가격": "£45.17",
#         "주소": "https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html"
#     },
#     {
#         "카테고리": "Travel",
#         "책 이름": "Full Moon over Noah’s ...",
#         "가격": "£49.43",
#         "주소": "https://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html"
#     },
#    // 중략...
#    {
#         "카테고리": "Fiction",
#         "책 이름": "Lost Among the Living",
#         "가격": "£27.70",
#         "주소": "https://books.toscrape.com/catalogue/lost-among-the-living_31/index.html"
#     },
#     {
#         "카테고리": "Fiction",
#         "책 이름": "A Spy's Devotion (The ...",
#         "가격": "£16.97",
#         "주소": "https://books.toscrape.com/catalogue/a-spys-devotion-the-regency-spies-of-london-1_3/index.html"
#     }
# ]
# ```

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from pprint import pprint
import json

# 웹 페이지 상호작용 객체 ActionChains
from selenium.webdriver.common.action_chains import ActionChains

# 키보드 객체
from selenium.webdriver.common.keys import Keys

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service)

# 대기 매커니즘 코드
driver.implicitly_wait(3)

url = "https://books.toscrape.com/"

driver.get(url)

category = ["Travel", "Romance", "Fiction"]
book_list_json = []
for change_category in category:

    category_change = driver.find_element(By.LINK_TEXT, change_category)

    category_change.click()

    while True:

        book_div = driver.find_elements(By.CSS_SELECTOR, "article.product_pod")

        for book_info in book_div:

            book_title = book_info.find_element(
                By.CSS_SELECTOR, "h3>a"
            )  # h3 안에 있는 a 태그를 찾음
            book_price = book_info.find_element(By.CSS_SELECTOR, "p.price_color")

            book_link = book_title.get_attribute("href")

            book_dict = {
                "카테고리": change_category,
                "책 이름": book_title.text,
                "가격": book_price.text,
                "주소": book_link,
            }

            book_list_json.append(book_dict)

        try:  # next 버튼이 있는지 찾기, 없으면 while문 나가고 다시 카테고리 고르기
            next_button = driver.find_element(By.LINK_TEXT, "next")
            next_button.click()
        except Exception as e:
            break

# json 파일에 저장
with open("book_list.json", "w") as file:
    json.dump(book_list_json, file, indent=4, ensure_ascii=False)

pprint(book_list_json)
# Out:
# [{'가격': '£45.17',
#   '주소': 'https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html',
#   '책 이름': "It's Only the Himalayas",
#   '카테고리': 'Travel'},
#  {'가격': '£49.43',
#   '주소': 'https://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html',
#   '책 이름': 'Full Moon over Noah’s ...',
#   '카테고리': 'Travel'},
#  {'가격': '£48.87',
#   '주소': 'https://books.toscrape.com/catalogue/see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html',
#   '책 이름': 'See America: A Celebration ...',
#   '카테고리': 'Travel'},
#  {'가격': '£36.94',
#   '주소': 'https://books.toscrape.com/catalogue/vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html',
#   '책 이름': 'Vagabonding: An Uncommon Guide ...',
#   '카테고리': 'Travel'},
#  {'가격': '£37.33',
#   '주소': 'https://books.toscrape.com/catalogue/under-the-tuscan-sun_504/index.html',
#   '책 이름': 'Under the Tuscan Sun',
#   '카테고리': 'Travel'},
#  {'가격': '£44.34',
#   '주소': 'https://books.toscrape.com/catalogue/a-summer-in-europe_458/index.html',
#   '책 이름': 'A Summer In Europe',
#   '카테고리': 'Travel'},
#  {'가격': '£30.54',
#   '주소': 'https://books.toscrape.com/catalogue/the-great-railway-bazaar_446/index.html',
#   '책 이름': 'The Great Railway Bazaar',
#   '카테고리': 'Travel'},
#  {'가격': '£56.88',
#   '주소': 'https://books.toscrape.com/catalogue/a-year-in-provence-provence-1_421/index.html',
#   '책 이름': 'A Year in Provence ...',
#   '카테고리': 'Travel'},
#  {'가격': '£23.21',
#   '주소': 'https://books.toscrape.com/catalogue/the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html',
#   '책 이름': 'The Road to Little ...',
#   '카테고리': 'Travel'},
#  {'가격': '£38.95',
#   '주소': 'https://books.toscrape.com/catalogue/neither-here-nor-there-travels-in-europe_198/index.html',
#   '책 이름': 'Neither Here nor There: ...',
#   '카테고리': 'Travel'},
#  {'가격': '£26.08',
#   '주소': 'https://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html',
#   '책 이름': '1,000 Places to See ...',
#   '카테고리': 'Travel'},
#  {'가격': '£25.27',
#   '주소': 'https://books.toscrape.com/catalogue/chase-me-paris-nights-2_977/index.html',
#   '책 이름': 'Chase Me (Paris Nights ...',
#   '카테고리': 'Romance'},
#  {'가격': '£34.53',
#   '주소': 'https://books.toscrape.com/catalogue/black-dust_976/index.html',
#   '책 이름': 'Black Dust',
#   '카테고리': 'Romance'},
#  {'가격': '£33.97',
#   '주소': 'https://books.toscrape.com/catalogue/her-backup-boyfriend-the-sorensen-family-1_896/index.html',
#   '책 이름': 'Her Backup Boyfriend (The ...',
#   '카테고리': 'Romance'},
#  {'가격': '£15.97',
#   '주소': 'https://books.toscrape.com/catalogue/first-and-first-five-boroughs-3_893/index.html',
#   '책 이름': 'First and First (Five ...',
#   '카테고리': 'Romance'},
#  {'가격': '£21.96',
#   '주소': 'https://books.toscrape.com/catalogue/fifty-shades-darker-fifty-shades-2_892/index.html',
#   '책 이름': 'Fifty Shades Darker (Fifty ...',
#   '카테고리': 'Romance'},
#  {'가격': '£24.12',
#   '주소': 'https://books.toscrape.com/catalogue/the-wedding-dress_864/index.html',
#   '책 이름': 'The Wedding Dress',
#   '카테고리': 'Romance'},
#  {'가격': '£55.99',
#   '주소': 'https://books.toscrape.com/catalogue/suddenly-in-love-lake-haven-1_835/index.html',
#   '책 이름': 'Suddenly in Love (Lake ...',
#   '카테고리': 'Romance'},
#  {'가격': '£16.24',
#   '주소': 'https://books.toscrape.com/catalogue/something-more-than-this_834/index.html',
#   '책 이름': 'Something More Than This',
#   '카테고리': 'Romance'},
#  {'가격': '£35.61',
#   '주소': 'https://books.toscrape.com/catalogue/doing-it-over-most-likely-to-1_802/index.html',
#   '책 이름': 'Doing It Over (Most ...',
#   '카테고리': 'Romance'},
#  {'가격': '£32.61',
#   '주소': 'https://books.toscrape.com/catalogue/the-wedding-pact-the-omalleys-2_767/index.html',
#   '책 이름': 'The Wedding Pact (The ...',
#   '카테고리': 'Romance'},
#  {'가격': '£28.82',
#   '주소': 'https://books.toscrape.com/catalogue/hold-your-breath-search-and-rescue-1_700/index.html',
#   '책 이름': 'Hold Your Breath (Search ...',
#   '카테고리': 'Romance'},
#  {'가격': '£40.83',
#   '주소': 'https://books.toscrape.com/catalogue/dirty-dive-bar-1_615/index.html',
#   '책 이름': 'Dirty (Dive Bar #1)',
#   '카테고리': 'Romance'},
#  {'가격': '£53.98',
#   '주소': 'https://books.toscrape.com/catalogue/take-me-home-tonight-rock-star-romance-3_605/index.html',
#   '책 이름': 'Take Me Home Tonight ...',
#   '카테고리': 'Romance'},
#  {'가격': '£47.67',
#   '주소': 'https://books.toscrape.com/catalogue/off-the-hook-fishing-for-trouble-1_601/index.html',
#   '책 이름': 'Off the Hook (Fishing ...',
#   '카테고리': 'Romance'},
#  {'가격': '£14.75',
#   '주소': 'https://books.toscrape.com/catalogue/a-gentlemans-position-society-of-gentlemen-3_584/index.html',
#   '책 이름': "A Gentleman's Position (Society ...",
#   '카테고리': 'Romance'},
#  {'가격': '£20.90',
#   '주소': 'https://books.toscrape.com/catalogue/sit-stay-love_486/index.html',
#   '책 이름': 'Sit, Stay, Love',
#   '카테고리': 'Romance'},
#  {'가격': '£31.30',
#   '주소': 'https://books.toscrape.com/catalogue/a-girls-guide-to-moving-on-new-beginnings-2_359/index.html',
#   '책 이름': "A Girl's Guide to ...",
#   '카테고리': 'Romance'},
#  {'가격': '£59.99',
#   '주소': 'https://books.toscrape.com/catalogue/the-perfect-play-play-by-play-1_352/index.html',
#   '책 이름': 'The Perfect Play (Play ...',
#   '카테고리': 'Romance'},
#  {'가격': '£12.87',
#   '주소': 'https://books.toscrape.com/catalogue/dark-lover-black-dagger-brotherhood-1_319/index.html',
#   '책 이름': 'Dark Lover (Black Dagger ...',
#   '카테고리': 'Romance'},
#  {'가격': '£13.38',
#   '주소': 'https://books.toscrape.com/catalogue/changing-the-game-play-by-play-2_317/index.html',
#   '책 이름': 'Changing the Game (Play ...',
#   '카테고리': 'Romance'},
#  {'가격': '£56.43',
#   '주소': 'https://books.toscrape.com/catalogue/a-walk-to-remember_312/index.html',
#   '책 이름': 'A Walk to Remember',
#   '카테고리': 'Romance'},
#  {'가격': '£12.25',
#   '주소': 'https://books.toscrape.com/catalogue/the-purest-hook-second-circle-tattoos-3_271/index.html',
#   '책 이름': 'The Purest Hook (Second ...',
#   '카테고리': 'Romance'},
#  {'가격': '£45.43',
#   '주소': 'https://books.toscrape.com/catalogue/the-obsession_268/index.html',
#   '책 이름': 'The Obsession',
#   '카테고리': 'Romance'},
#  {'가격': '£11.10',
#   '주소': 'https://books.toscrape.com/catalogue/reservations-for-two_211/index.html',
#   '책 이름': 'Reservations for Two',
#   '카테고리': 'Romance'},
#  {'가격': '£27.41',
#   '주소': 'https://books.toscrape.com/catalogue/best-of-my-love-fools-gold-20_127/index.html',
#   '책 이름': 'Best of My Love ...',
#   '카테고리': 'Romance'},
#  {'가격': '£39.77',
#   '주소': 'https://books.toscrape.com/catalogue/where-lightning-strikes-bleeding-stars-3_96/index.html',
#   '책 이름': 'Where Lightning Strikes (Bleeding ...',
#   '카테고리': 'Romance'},
#  {'가격': '£48.71',
#   '주소': 'https://books.toscrape.com/catalogue/this-one-moment-pushing-limits-1_88/index.html',
#   '책 이름': 'This One Moment (Pushing ...',
#   '카테고리': 'Romance'},
#  {'가격': '£28.34',
#   '주소': 'https://books.toscrape.com/catalogue/rhythm-chord-malykhin_47/index.html',
#   '책 이름': 'Rhythm, Chord & Malykhin',
#   '카테고리': 'Romance'},
#  {'가격': '£38.92',
#   '주소': 'https://books.toscrape.com/catalogue/my-perfect-mistake-over-the-top-1_35/index.html',
#   '책 이름': 'My Perfect Mistake (Over ...',
#   '카테고리': 'Romance'},
#  {'가격': '£58.99',
#   '주소': 'https://books.toscrape.com/catalogue/listen-to-me-fusion-1_29/index.html',
#   '책 이름': 'Listen to Me (Fusion ...',
#   '카테고리': 'Romance'},
#  {'가격': '£34.74',
#   '주소': 'https://books.toscrape.com/catalogue/imperfect-harmony_26/index.html',
#   '책 이름': 'Imperfect Harmony',
#   '카테고리': 'Romance'},
#  {'가격': '£39.24',
#   '주소': 'https://books.toscrape.com/catalogue/fighting-fate-fighting-6_18/index.html',
#   '책 이름': 'Fighting Fate (Fighting #6)',
#   '카테고리': 'Romance'},
#  {'가격': '£47.09',
#   '주소': 'https://books.toscrape.com/catalogue/deep-under-walker-security-1_15/index.html',
#   '책 이름': 'Deep Under (Walker Security ...',
#   '카테고리': 'Romance'},
#  {'가격': '£41.24',
#   '주소': 'https://books.toscrape.com/catalogue/charitys-cross-charles-towne-belles-4_12/index.html',
#   '책 이름': "Charity's Cross (Charles Towne ...",
#   '카테고리': 'Romance'},
#  {'가격': '£37.26',
#   '주소': 'https://books.toscrape.com/catalogue/bounty-colorado-mountain-7_9/index.html',
#   '책 이름': 'Bounty (Colorado Mountain #7)',
#   '카테고리': 'Romance'},
#  {'가격': '£50.10',
#   '주소': 'https://books.toscrape.com/catalogue/soumission_998/index.html',
#   '책 이름': 'Soumission',
#   '카테고리': 'Fiction'},
#  {'가격': '£47.61',
#   '주소': 'https://books.toscrape.com/catalogue/private-paris-private-10_958/index.html',
#   '책 이름': 'Private Paris (Private #10)',
#   '카테고리': 'Fiction'},
#  {'가격': '£50.27',
#   '주소': 'https://books.toscrape.com/catalogue/we-love-you-charlie-freeman_954/index.html',
#   '책 이름': 'We Love You, Charlie ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£17.27',
#   '주소': 'https://books.toscrape.com/catalogue/thirst_946/index.html',
#   '책 이름': 'Thirst',
#   '카테고리': 'Fiction'},
#  {'가격': '£54.11',
#   '주소': 'https://books.toscrape.com/catalogue/the-murder-that-never-was-forensic-instincts-5_939/index.html',
#   '책 이름': 'The Murder That Never ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£21.04',
#   '주소': 'https://books.toscrape.com/catalogue/tuesday-nights-in-1980_870/index.html',
#   '책 이름': 'Tuesday Nights in 1980',
#   '카테고리': 'Fiction'},
#  {'가격': '£42.15',
#   '주소': 'https://books.toscrape.com/catalogue/the-vacationers_863/index.html',
#   '책 이름': 'The Vacationers',
#   '카테고리': 'Fiction'},
#  {'가격': '£51.36',
#   '주소': 'https://books.toscrape.com/catalogue/the-regional-office-is-under-attack_858/index.html',
#   '책 이름': 'The Regional Office Is ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£53.53',
#   '주소': 'https://books.toscrape.com/catalogue/finders-keepers-bill-hodges-trilogy-2_807/index.html',
#   '책 이름': 'Finders Keepers (Bill Hodges ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£27.88',
#   '주소': 'https://books.toscrape.com/catalogue/the-time-keeper_766/index.html',
#   '책 이름': 'The Time Keeper',
#   '카테고리': 'Fiction'},
#  {'가격': '£52.67',
#   '주소': 'https://books.toscrape.com/catalogue/the-testament-of-mary_765/index.html',
#   '책 이름': 'The Testament of Mary',
#   '카테고리': 'Fiction'},
#  {'가격': '£25.85',
#   '주소': 'https://books.toscrape.com/catalogue/the-first-hostage-jb-collins-2_749/index.html',
#   '책 이름': 'The First Hostage (J.B. ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£45.21',
#   '주소': 'https://books.toscrape.com/catalogue/take-me-with-you_741/index.html',
#   '책 이름': 'Take Me with You',
#   '카테고리': 'Fiction'},
#  {'가격': '£26.41',
#   '주소': 'https://books.toscrape.com/catalogue/still-life-with-bread-crumbs_738/index.html',
#   '책 이름': 'Still Life with Bread ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£55.84',
#   '주소': 'https://books.toscrape.com/catalogue/shtum_733/index.html',
#   '책 이름': 'Shtum',
#   '카테고리': 'Fiction'},
#  {'가격': '£41.56',
#   '주소': 'https://books.toscrape.com/catalogue/my-name-is-lucy-barton_720/index.html',
#   '책 이름': 'My Name Is Lucy ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£24.48',
#   '주소': 'https://books.toscrape.com/catalogue/my-mrs-brown_719/index.html',
#   '책 이름': 'My Mrs. Brown',
#   '카테고리': 'Fiction'},
#  {'가격': '£28.90',
#   '주소': 'https://books.toscrape.com/catalogue/mr-mercedes-bill-hodges-trilogy-1_717/index.html',
#   '책 이름': 'Mr. Mercedes (Bill Hodges ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£10.60',
#   '주소': 'https://books.toscrape.com/catalogue/i-am-pilgrim-pilgrim-1_703/index.html',
#   '책 이름': 'I Am Pilgrim (Pilgrim ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£27.09',
#   '주소': 'https://books.toscrape.com/catalogue/eligible-the-austen-project-4_692/index.html',
#   '책 이름': 'Eligible (The Austen Project ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£14.39',
#   '주소': 'https://books.toscrape.com/catalogue/eight-hundred-grapes_690/index.html',
#   '책 이름': 'Eight Hundred Grapes',
#   '카테고리': 'Fiction'},
#  {'가격': '£11.21',
#   '주소': 'https://books.toscrape.com/catalogue/dear-mr-knightley_684/index.html',
#   '책 이름': 'Dear Mr. Knightley',
#   '카테고리': 'Fiction'},
#  {'가격': '£25.01',
#   '주소': 'https://books.toscrape.com/catalogue/cometh-the-hour-the-clifton-chronicles-6_681/index.html',
#   '책 이름': 'Cometh the Hour (The ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£17.03',
#   '주소': 'https://books.toscrape.com/catalogue/balloon-animals_665/index.html',
#   '책 이름': 'Balloon Animals',
#   '카테고리': 'Fiction'},
#  {'가격': '£39.72',
#   '주소': 'https://books.toscrape.com/catalogue/a-man-called-ove_653/index.html',
#   '책 이름': 'A Man Called Ove',
#   '카테고리': 'Fiction'},
#  {'가격': '£46.29',
#   '주소': 'https://books.toscrape.com/catalogue/the-silent-sister-riley-macpherson-1_641/index.html',
#   '책 이름': 'The Silent Sister (Riley ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£56.54',
#   '주소': 'https://books.toscrape.com/catalogue/the-dinner-party_635/index.html',
#   '책 이름': 'The Dinner Party',
#   '카테고리': 'Fiction'},
#  {'가격': '£59.45',
#   '주소': 'https://books.toscrape.com/catalogue/the-improbability-of-love_607/index.html',
#   '책 이름': 'The Improbability of Love',
#   '카테고리': 'Fiction'},
#  {'가격': '£13.34',
#   '주소': 'https://books.toscrape.com/catalogue/mothering-sunday_600/index.html',
#   '책 이름': 'Mothering Sunday',
#   '카테고리': 'Fiction'},
#  {'가격': '£45.14',
#   '주소': 'https://books.toscrape.com/catalogue/lies-and-other-acts-of-love_596/index.html',
#   '책 이름': 'Lies and Other Acts ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£16.34',
#   '주소': 'https://books.toscrape.com/catalogue/daredevils_590/index.html',
#   '책 이름': 'Daredevils',
#   '카테고리': 'Fiction'},
#  {'가격': '£48.48',
#   '주소': 'https://books.toscrape.com/catalogue/112263_583/index.html',
#   '책 이름': '11/22/63',
#   '카테고리': 'Fiction'},
#  {'가격': '£28.03',
#   '주소': 'https://books.toscrape.com/catalogue/the-shack_576/index.html',
#   '책 이름': 'The Shack',
#   '카테고리': 'Fiction'},
#  {'가격': '£51.15',
#   '주소': 'https://books.toscrape.com/catalogue/the-high-mountains-of-portugal_547/index.html',
#   '책 이름': 'The High Mountains of ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£58.54',
#   '주소': 'https://books.toscrape.com/catalogue/millers-valley_534/index.html',
#   '책 이름': "Miller's Valley",
#   '카테고리': 'Fiction'},
#  {'가격': '£21.96',
#   '주소': 'https://books.toscrape.com/catalogue/hystopia-a-novel_523/index.html',
#   '책 이름': 'Hystopia: A Novel',
#   '카테고리': 'Fiction'},
#  {'가격': '£42.78',
#   '주소': 'https://books.toscrape.com/catalogue/the-bourne-identity-jason-bourne-1_492/index.html',
#   '책 이름': 'The Bourne Identity (Jason ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£40.20',
#   '주소': 'https://books.toscrape.com/catalogue/sister-dear_485/index.html',
#   '책 이름': 'Sister Dear',
#   '카테고리': 'Fiction'},
#  {'가격': '£49.67',
#   '주소': 'https://books.toscrape.com/catalogue/memoirs-of-a-geisha_477/index.html',
#   '책 이름': 'Memoirs of a Geisha',
#   '카테고리': 'Fiction'},
#  {'가격': '£19.02',
#   '주소': 'https://books.toscrape.com/catalogue/me-before-you-me-before-you-1_434/index.html',
#   '책 이름': 'Me Before You (Me ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£40.32',
#   '주소': 'https://books.toscrape.com/catalogue/deception-point_426/index.html',
#   '책 이름': 'Deception Point',
#   '카테고리': 'Fiction'},
#  {'가격': '£24.73',
#   '주소': 'https://books.toscrape.com/catalogue/the-little-paris-bookshop_407/index.html',
#   '책 이름': 'The Little Paris Bookshop',
#   '카테고리': 'Fiction'},
#  {'가격': '£45.56',
#   '주소': 'https://books.toscrape.com/catalogue/the-firm_404/index.html',
#   '책 이름': 'The Firm',
#   '카테고리': 'Fiction'},
#  {'가격': '£44.58',
#   '주소': 'https://books.toscrape.com/catalogue/the-expatriates_401/index.html',
#   '책 이름': 'The Expatriates',
#   '카테고리': 'Fiction'},
#  {'가격': '£34.22',
#   '주소': 'https://books.toscrape.com/catalogue/siddhartha_393/index.html',
#   '책 이름': 'Siddhartha',
#   '카테고리': 'Fiction'},
#  {'가격': '£59.98',
#   '주소': 'https://books.toscrape.com/catalogue/last-one-home-new-beginnings-1_383/index.html',
#   '책 이름': 'Last One Home (New ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£58.00',
#   '주소': 'https://books.toscrape.com/catalogue/digital-fortress_369/index.html',
#   '책 이름': 'Digital Fortress',
#   '카테고리': 'Fiction'},
#  {'가격': '£26.58',
#   '주소': 'https://books.toscrape.com/catalogue/atlas-shrugged_314/index.html',
#   '책 이름': 'Atlas Shrugged',
#   '카테고리': 'Fiction'},
#  {'가격': '£23.21',
#   '주소': 'https://books.toscrape.com/catalogue/three-martini-lunch_290/index.html',
#   '책 이름': 'Three-Martini Lunch',
#   '카테고리': 'Fiction'},
#  {'가격': '£26.26',
#   '주소': 'https://books.toscrape.com/catalogue/the-nightingale_267/index.html',
#   '책 이름': 'The Nightingale',
#   '카테고리': 'Fiction'},
#  {'가격': '£27.41',
#   '주소': 'https://books.toscrape.com/catalogue/the-infinities_257/index.html',
#   '책 이름': 'The Infinities',
#   '카테고리': 'Fiction'},
#  {'가격': '£52.51',
#   '주소': 'https://books.toscrape.com/catalogue/the-husbands-secret_256/index.html',
#   '책 이름': "The Husband's Secret",
#   '카테고리': 'Fiction'},
#  {'가격': '£22.96',
#   '주소': 'https://books.toscrape.com/catalogue/the-da-vinci-code-robert-langdon-2_240/index.html',
#   '책 이름': 'The Da Vinci Code ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£22.10',
#   '주소': 'https://books.toscrape.com/catalogue/the-art-of-fielding_228/index.html',
#   '책 이름': 'The Art of Fielding',
#   '카테고리': 'Fiction'},
#  {'가격': '£12.47',
#   '주소': 'https://books.toscrape.com/catalogue/lila-gilead-3_190/index.html',
#   '책 이름': 'Lila (Gilead #3)',
#   '카테고리': 'Fiction'},
#  {'가격': '£44.97',
#   '주소': 'https://books.toscrape.com/catalogue/jurassic-park-jurassic-park-1_180/index.html',
#   '책 이름': 'Jurassic Park (Jurassic Park ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£41.00',
#   '주소': 'https://books.toscrape.com/catalogue/inferno-robert-langdon-4_176/index.html',
#   '책 이름': 'Inferno (Robert Langdon #4)',
#   '카테고리': 'Fiction'},
#  {'가격': '£49.13',
#   '주소': 'https://books.toscrape.com/catalogue/crazy-rich-asians-crazy-rich-asians-1_143/index.html',
#   '책 이름': 'Crazy Rich Asians (Crazy ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£22.11',
#   '주소': 'https://books.toscrape.com/catalogue/big-little-lies_129/index.html',
#   '책 이름': 'Big Little Lies',
#   '카테고리': 'Fiction'},
#  {'가격': '£16.78',
#   '주소': 'https://books.toscrape.com/catalogue/the-course-of-love_109/index.html',
#   '책 이름': 'The Course of Love',
#   '카테고리': 'Fiction'},
#  {'가격': '£51.96',
#   '주소': 'https://books.toscrape.com/catalogue/when-im-gone_95/index.html',
#   '책 이름': "When I'm Gone",
#   '카테고리': 'Fiction'},
#  {'가격': '£12.34',
#   '주소': 'https://books.toscrape.com/catalogue/the-silent-wife_83/index.html',
#   '책 이름': 'The Silent Wife',
#   '카테고리': 'Fiction'},
#  {'가격': '£30.66',
#   '주소': 'https://books.toscrape.com/catalogue/the-bette-davis-club_59/index.html',
#   '책 이름': 'The Bette Davis Club',
#   '카테고리': 'Fiction'},
#  {'가격': '£57.20',
#   '주소': 'https://books.toscrape.com/catalogue/kitchens-of-the-great-midwest_28/index.html',
#   '책 이름': 'Kitchens of the Great ...',
#   '카테고리': 'Fiction'},
#  {'가격': '£39.07',
#   '주소': 'https://books.toscrape.com/catalogue/bright-lines_11/index.html',
#   '책 이름': 'Bright Lines',
#   '카테고리': 'Fiction'}]
