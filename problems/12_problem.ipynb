# %% [markdown]
# 영화 평점 데이터셋을 사용하여 실습을 진행합니다.
#
# 이 데이터 세트에는 사용자들이 영화에 부여한 평점 정보가 포함되어 있으며, 각 사용자의 나이와 직업, 그리고 평가한 영화의 장르 정보가 포함되어 있습니다.
#
# <aside>
# 💡 각 문제를 읽고 문제를 해결하기 위한 코드를 작성합니다.
#
# </aside>
#
# ## [1] 데이터 불러오기
#
# [movie_ratings.csv](https://prod-files-secure.s3.us-west-2.amazonaws.com/f2678325-6f7b-4a25-b188-86c42030d6d5/5884c8a4-2a89-4407-a8d6-7c18df7f177d/movie_ratings.csv)
#
# 1. 파일을 불러와서 데이터프레임을 생성하세요.
#
# ## **[2] 데이터 확인하기**
#
# 1. 데이터의 처음 5행과 마지막 5행을 출력하세요.
# 2. 데이터의 구조, 즉 행과 열의 수를 출력하세요.
# 3. 각 컬럼의 데이터 타입을 출력하세요.
#
# ## **[3] 범주형 자료 확인하기**
#
# 1. 영화 장르(**`Genre`**) 컬럼의 유니크한 값과 각 장르별 영화 수를 출력하세요.
# 2. 사용자의 직업(**`Occupation`**) 컬럼의 유니크한 값과 각 직업별 사용자 수를 출력하세요.
#
# ## [4] **수치형 자료 확인하기**
#
# 1. 사용자 나이(**`Age`**) 컬럼의 평균, 최소값, 최대값을 출력하세요.
# 2. 영화 평점(**`Rating`**) 컬럼에 대한 기술 통계량(평균, 표준편차, 최소값, 최대값, 사분위수)을 출력하세요.

# %%
import pandas as pd

movie_ratings = pd.read_csv("data/movie_ratings.csv")


print(movie_ratings.head())

print(movie_ratings.tail())

print(movie_ratings.shape)

print(movie_ratings.dtypes)

print(
    movie_ratings["Genre"].unique(),
)

print(movie_ratings["Genre"].value_counts())

print(
    movie_ratings["Occupation"].unique(),
)

print(movie_ratings["Occupation"].value_counts())


print(
    movie_ratings["Age"].mean(), movie_ratings["Age"].max(), movie_ratings["Age"].min()
)

print(movie_ratings["Rating"].describe())
# Out:
#    UserID  MovieID  Rating  Age  Occupation    Genre
# 0      45        8       4   55  Unemployed   Horror
# 1      48        5       3   15    Engineer   Action
# 2      65        4       2   55     Student  Romance
# 3      68        6       5   45      Doctor   Comedy
# 4      68        7       4   25    Engineer  Romance
#      UserID  MovieID  Rating  Age Occupation    Genre
# 495       4        4       4   50     Doctor   Action
# 496      13       14       4   55    Student   Horror
# 497      59        5       5   40    Student   Comedy
# 498       2       20       3   40     Artist   Action
# 499       1        7       2   20     Artist  Romance
# (500, 6)
# UserID         int64
# MovieID        int64
# Rating         int64
# Age            int64
# Occupation    object
# Genre         object
# dtype: object
# ['Horror' 'Action' 'Romance' 'Comedy' 'Drama']
# 5
# ['Unemployed' 'Engineer' 'Student' 'Doctor' 'Artist']
# 5
# 38.52 60 15
# count    500.000000
# ...
