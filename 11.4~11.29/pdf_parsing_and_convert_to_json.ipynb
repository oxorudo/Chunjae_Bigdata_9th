# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os

# 셀레니움 웹드라이버 설정
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # 브라우저 창을 열지 않고 실행
driver = webdriver.Chrome()



# 로그인 페이지 접근 및 로그인 처리
driver.get("https://www.milkt.co.kr/Login/Login")
time.sleep(1)  # 페이지 로드 대기

# 로그인 요소 찾기 및 로그인 정보 입력
driver.find_element(By.ID, 'input_id').send_keys("") # 아이디
driver.find_element(By.ID, 'input_pw').send_keys("") # 비번
driver.find_element(By.ID, 'btn_login').click()
time.sleep(2)  # 로그인 후 로딩 대기

main_window = driver.current_window_handle
for handle in driver.window_handles:
    if handle != main_window:
        driver.switch_to.window(handle)
        time.sleep(2)  # 팝업 창에서 로딩이 필요한 경우 대기
        driver.close()  # 팝업 창 닫기
        driver.switch_to.window(main_window)  # 원래 창으로 돌아오기
        
try:
    close_button = driver.find_element(By.CLASS_NAME, "btn_close")  # 실제 팝업 닫기 버튼 클래스명 필요
    close_button.click()
    print("레이어 팝업이 닫혔습니다.")
except:
    print("레이어 팝업이 없습니다.")

# 필요한 페이지로 이동
driver.get("https://www.milkt.co.kr/LectureMaterial/LectureMaterial?intPageSize=30&strCode=A04&strSubCode=A0402&inGrade=1&inTerm=1&strlectTit=&strlectCont=")
time.sleep(2)

main_window = driver.current_window_handle
for handle in driver.window_handles:
    if handle != main_window:
        driver.switch_to.window(handle)
        time.sleep(1)  # 팝업 창에서 로딩이 필요한 경우 대기
        driver.close()  # 팝업 창 닫기
        driver.switch_to.window(main_window)  # 원래 창으로 돌아오기


# 위 페이지를 들어가고, 파일을 하나하나 다운로드 하면 된다. 전체 선택 후 다운로드하는 방법은 자동 다운로드 옵션이 미체크 되어있어 불가능.
# beyond는 뺴고 다운로드해야한다.

# %%
#  최종 코드

import pdfplumber
import fitz  # PyMuPDF
import os
import re
import json

def extract_lesson_titles(page): # 페이지에서 "Lesson" 제목을 추출하는 함수
    text = page.extract_text()  # 페이지의 텍스트를 추출
    lesson_titles = re.findall(r'Lesson \d+\. (.+?)\s*\n', text)  # "Lesson" 번호와 제목을 정규식으로 찾음
    return lesson_titles

def extract_data_from_table(row): # 테이블의 행에서 예문과 예문 뜻을 분리하는 함수
    example_sentence, example_meaning = "", ""
    if re.search(r'[A-Za-z]+.*?[.!?]\s+[가-힣]', row[6]):  # 영어와 한글이 섞인 패턴을 찾음
        parts = re.split(r'(?<=[.!?])\s+(?=[가-힣])', row[6], 1)  # 영어 문장과 한글 뜻을 분리
    elif re.search(r'[A-Za-z]+\s+[가-힣]', row[6]):
        parts = re.split(r'(?<=[A-Za-z])\s+(?=[가-힣])', row[6], 1)  # 영어 단어와 한글 뜻을 분리
    elif "\n" in row[6]:
        parts = row[6].split("\n", 1)  # 개행으로 구분된 경우 분리
    else:
        parts = [row[6].strip(), ""]  # 기본적으로 공백 제거 후 할당

    example_sentence = remove_newlines(parts[0].strip())  # 예문에서 개행 제거
    mixed = extract_sentences_with_korean(example_sentence)  # 예문에서 한국어 문장을 추출
    example_meaning = remove_newlines(parts[1].strip()) if len(parts) > 1 else ""  # 예문 뜻에서 개행 제거
    
    # 예문과 예문 뜻에서 한국어 문장이 섞여 있는 경우 처리
    if example_meaning.startswith('씨'):
        concat = example_sentence + example_meaning
        example_meaning = extract_sentences_with_korean(concat)[0]
        example_sentence = concat.replace(example_meaning, '')
    
    if len(mixed) > 0: 
        if mixed[0] in example_sentence:
            example_sentence = example_sentence.replace(mixed[0], '')
            example_meaning = mixed[0] + ' ' + example_meaning

    # 품사와 단어 뜻을 정규식으로 추출
    pos_match = re.search(r'(\w+)\)\s*', row[3])
    if pos_match:
        part_of_speech = pos_match.group(1)  # 품사 추출
        meaning_text = re.sub(r'\s*\(\w+\)\s*', '', row[3]).strip()  # 뜻에서 품사 제거
    else:
        part_of_speech = ""
        meaning_text = row[3].strip()

    # 반환할 단어 정보 사전 생성
    return {
        "단어": remove_newlines(row[0].strip()),
        "단어 뜻": meaning_text.replace(part_of_speech + ')', '').strip(),
        "품사": part_of_speech,
        "예문": example_sentence.strip(),
        "예문 뜻": example_meaning.strip(),
    }

def remove_newlines(text):  # 문자열에서 개행 문자를 제거하는 함수
    return text.replace("\n", " ").replace("\r", "")

def extract_sentences_with_korean(text):  # 영문장에서 한국어가 존재시 재 추출하는 함수
    sentences = re.split(r'(?<=[.?!])\s+', text)
    korean_sentences = [sentence for sentence in sentences if re.search(r'[가-힣]', sentence)]
    return korean_sentences

def safe_filename(filename):  # 파일 이름에서 안전하지 않은 문자를 제거하는 함수
    return re.sub(r'[\/\:*?"<>|]', "", filename)

def pdf_to_json(pdf_path, output_directory):  # beyond.pdf를 제외한 pdf용 : pdfplumber를 사용하여 PDF를 JSON으로 변환하는 함수
    with pdfplumber.open(pdf_path) as pdf:
        for page_number, page in enumerate(pdf.pages):
            lesson_titles = extract_lesson_titles(page)  # "Lesson" 제목 추출
            title_text = " - ".join(lesson_titles)  # 제목을 파일명으로 변환
            safe_title_text = safe_filename(title_text)  # 안전한 파일명 변환
            data = []
            tables = page.extract_tables()  # 페이지에서 테이블 추출
            for table in tables:
                for row in table:
                    if len(row) > 0:
                        entry = extract_data_from_table(row)  # 테이블 행을 데이터로 변환
                        if any(entry.values()):
                            data.append(entry)
            # JSON 파일로 저장
            output_file = os.path.join(output_directory, f"{os.path.basename(pdf_path).replace('.pdf', '')}_page_{page_number + 1}_{safe_title_text}.json")
            with open(output_file, "w", encoding="utf-8") as json_file:
                json.dump(data, json_file, ensure_ascii=False, indent=4)
            print(f"Parsed data for {pdf_path} page {page_number + 1}:", data)

def clean_text(text):  # 텍스트의 양끝 공백을 제거하는 함수
    return text.strip()

def format_sentence(sentence):  # 예문 형식을 정리하는 함수
    if re.search(r'\s햄', sentence):
        sentence = sentence.replace(".  햄", "\n햄")
    return sentence

def extract_words_from_pdf_by_page(pdf_path, output_dir="output_pages"):  # beyond.pdf용 : PyMuPDF를 사용하여 페이지별로 PDF 단어를 추출하는 함수
    document = fitz.open(pdf_path)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for page_num in range(document.page_count):
        page = document.load_page(page_num)
        text = format_sentence(page.get_text().replace('"', ''))
        text = text.replace(". 나", "\n나").replace("\n는", "는").replace(". 우", "\n우").replace("\n만", "만").replace("\n다", "다").replace("\n있다", "있다").replace("\n은편에", "은편에").replace("그녀는", "\n그녀는").replace("학습", "\n학습").replace("\nstudents", "students")
        
        # Lesson 제목을 뽑아서 파일 이름에 포함
        lesson_title = re.search(r'Lesson \d+\. (.+?)\s*\n', text)
        title_text = lesson_title.group(1) if lesson_title else f"Page_{page_num + 1}"
        safe_title_text = safe_filename(title_text)

        # 단어 정보 추출 패턴 정의
        pattern = r"(?P<단어>\w+)\s+(?P<품사>[a-z.]+)\s+(?P<단어_뜻>.+?)\n(?P<예문>.+?)\n(?P<예문_뜻>.+?)\n"
        if page_num == 12 or page_num == 23:
            pattern = r"(?P<단어>\w+(?:\s\w+)*)\s+(?P<품사>[a-z.]+)\s+(?P<단어_뜻>.+?)\n(?P<예문>.+?)\n(?P<예문_뜻>.+?)\n"
        matches = re.finditer(pattern, text, re.MULTILINE)
        
        page_words = []
        for match in matches:
            word_info = {
                "단어": clean_text(match.group("단어")),
                "단어 뜻": clean_text(match.group("단어_뜻")),
                "품사": clean_text(match.group("품사")),
                "예문": clean_text(match.group("예문")),
                "예문 뜻": clean_text(match.group("예문_뜻"))
            }
            if word_info["단어"] and word_info["예문"]:
                page_words.append(word_info)
        
        # JSON 파일 저장
        output_file = os.path.join(output_dir, f"{os.path.basename(pdf_path).replace('.pdf', '')}_page_{page_num + 1}_{safe_title_text}.json")
        with open(output_file, "w", encoding="utf-8") as json_file:
            json.dump(page_words, json_file, ensure_ascii=False, indent=4)
    


def process_pdfs(pdf_directory, output_directory):
    os.makedirs(output_directory, exist_ok=True)
    for pdf_file in os.listdir(pdf_directory):
        pdf_path = os.path.join(pdf_directory, pdf_file)
        if pdf_file.endswith(".pdf"):
            if pdf_file == "beyond.pdf":
                print(f"{pdf_file}를 처리하는 중...")
                extract_words_from_pdf_by_page(pdf_path, output_dir=output_directory)
            else:
                pdf_to_json(pdf_path, output_directory)

# 디렉토리 설정
pdf_directory = "./pdf_words" # pdf 넣을 폴더
output_directory = "./json_words" # 변환된 json들이 들어갈 폴더

# PDF 파일 처리
process_pdfs(pdf_directory, output_directory)
# Out:
# Parsed data for ./pdf_words/fly1.pdf page 1: [{'단어': 'bird', '단어 뜻': '새', '품사': '', '예문': 'A bird is in the tree.', '예문 뜻': '새가 나무에 있다.'}, {'단어': 'idea', '단어 뜻': '생각', '품사': '', '예문': 'Matt has a good idea.', '예문 뜻': '맷에게 좋은 생각이 있다.'}, {'단어': 'wing', '단어 뜻': '날개', '품사': '', '예문': 'Chickens have wings.', '예문 뜻': '닭은 날개를 가지고 있다.'}, {'단어': 'fly', '단어 뜻': '날다', '품사': '', '예문': 'Spiderman can’t fly.', '예문 뜻': '스파이더맨은 날 수 없다.'}, {'단어': 'wind', '단어 뜻': '바람', '품사': '', '예문': 'The wind was strong.', '예문 뜻': '바람이 강했다.'}, {'단어': 'car', '단어 뜻': '자동차', '품사': '', '예문': 'Is this your car?', '예문 뜻': '이것은 네 차니?'}, {'단어': 'sky', '단어 뜻': '하늘', '품사': '', '예문': 'Look at the sky.', '예문 뜻': '하늘을 봐.'}, {'단어': 'airplane', '단어 뜻': '비행기', '품사': '', '예문': 'The airplane is in the sky.', '예문 뜻': '비행기가 하늘에 있다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 2: [{'단어': 'cousin', '단어 뜻': '사촌', '품사': '', '예문': 'My cousins are kind.', '예문 뜻': '내 사촌들은 친절하다.'}, {'단어': 'notebook', '단어 뜻': '공책', '품사': '', '예문': 'Do you have a new notebook?', '예문 뜻': '너는 새 공책이 있니?'}, {'단어': 'vacation', '단어 뜻': '방학', '품사': '', '예문': 'I like summer vacation.', '예문 뜻': '나는 여름 방학이 좋다.'}, {'단어': 'come', '단어 뜻': '오다', '품사': '', '예문': 'Can you come here?', '예문 뜻': '여기로 올 수 있니?'}, {'단어': 'museum', '단어 뜻': '박물관', '품사': '', '예문': 'Where is the museum?', '예문 뜻': '박물관이 어디에 있니?'}, {'단어': 'animal', '단어 뜻': '동물', '품사': '', '예문': 'Kevin loves animals.', '예문 뜻': '케빈은 동물을 정말 좋아한다.'}, {'단어': 'horse', '단어 뜻': '말', '품사': '', '예문': 'What do horses eat?', '예문 뜻': '말은 무엇을 먹니?'}, {'단어': 'grass', '단어 뜻': '풀, 잔디', '품사': '', '예문': 'Don’t sit on the grass.', '예문 뜻': '잔디 위에 앉지 마.'}]
# Parsed data for ./pdf_words/fly1.pdf page 3: [{'단어': 'yes', '단어 뜻': '네, 응', '품사': '', '예문': 'Yes, it’s mine.', '예문 뜻': '응, 그것은 내 거야.'}, {'단어': 'white', '단어 뜻': '흰', '품사': '', '예문': 'Look at that white rabbit.', '예문 뜻': '저 흰 토끼를 봐.'}, {'단어': 'clean', '단어 뜻': '깨끗한', '품사': '', '예문': 'My room is clean now.', '예문 뜻': '내 방은 이제 깨끗하다.'}, {'단어': 'plus', '단어 뜻': '~을 더하여', '품사': '', '예문': 'Two plus three is five.', '예문 뜻': '2 더하기 3은 5이다.'}, {'단어': 'break', '단어 뜻': '부수다, 깨다', '품사': '', '예문': 'Don’t break the eggs.', '예문 뜻': '달걀을 깨지 마라.'}, {'단어': 'building', '단어 뜻': '건물', '품사': '', '예문': 'The building is very old.', '예문 뜻': '그 건물은 매우 오래되었다.'}, {'단어': 'prize', '단어 뜻': '상', '품사': '', '예문': 'The prize was yellow socks.', '예문 뜻': '상은 노란 양말이었다.'}, {'단어': 'for', '단어 뜻': '~을 위하여', '품사': '', '예문': 'Is this for your dad?', '예문 뜻': '이것은 네 아빠를 위한 것이니?'}]
# Parsed data for ./pdf_words/fly1.pdf page 4: [{'단어': 'borrow', '단어 뜻': '빌리다', '품사': '', '예문': 'Can I borrow your pencil?', '예문 뜻': '네 연필을 빌릴 수 있을까?'}, {'단어': 'tomorrow', '단어 뜻': '내일', '품사': '', '예문': "Let's meet at two tomorrow.", '예문 뜻': '내일 두 시에 만나자.'}, {'단어': 'sleep', '단어 뜻': '자다', '품사': '', '예문': "It's time to sleep.", '예문 뜻': '잘 시간이다.'}, {'단어': 'wet', '단어 뜻': '젖은', '품사': '', '예문': 'My shoes are wet.', '예문 뜻': '내 신발이 젖었다.'}, {'단어': 'hello', '단어 뜻': '안녕하세요', '품사': '', '예문': 'Hello, my name is Susan.', '예문 뜻': '안녕하세요, 제 이름은 수잔입니다.'}, {'단어': 'early', '단어 뜻': '일찍', '품사': '', '예문': 'I get up early in the morning.', '예문 뜻': '나는 아침에 일찍 일어난다.'}, {'단어': 'farm', '단어 뜻': '농장', '품사': '', '예문': 'Are there many cows on the farm?', '예문 뜻': '그 농장에는 젖소가 많니?'}, {'단어': 'present', '단어 뜻': '선물', '품사': '', '예문': 'This present is for you.', '예문 뜻': '이 선물은 너를 위한 거야.'}]
# Parsed data for ./pdf_words/fly1.pdf page 5: [{'단어': 'always', '단어 뜻': '항상, 언제나', '품사': '', '예문': 'She always carries that doll.', '예문 뜻': '그녀는 항상 저 인형을 가지고 다닌다.'}, {'단어': 'sister', '단어 뜻': '언니, 누나, 여동\n생', '품사': '', '예문': 'Is your sister cute?', '예문 뜻': '네 여동생은 귀엽니?'}, {'단어': 'name', '단어 뜻': '이름', '품사': '', '예문': 'Her name is Lucy.', '예문 뜻': '그녀의 이름은 루시야.'}, {'단어': 'show', '단어 뜻': '보여 주다', '품사': '', '예문': 'Jamie showed his photos.', '예문 뜻': '제이미는 그의 사진들을 보여 주었다.'}, {'단어': 'story', '단어 뜻': '이야기', '품사': '', '예문': 'The story was fun.', '예문 뜻': '그 이야기는 재미있었다.'}, {'단어': 'daughter', '단어 뜻': '딸', '품사': '', '예문': 'Do they have a daughter?', '예문 뜻': '그들은 딸이 한 명 있니?'}, {'단어': 'afraid', '단어 뜻': '두려워하는, 겁내\n는', '품사': '', '예문': "Don't be afraid.", '예문 뜻': '겁내지 마.'}, {'단어': 'writer', '단어 뜻': '작가', '품사': '', '예문': 'The writer is reading a book.', '예문 뜻': '그 작가는 책을 읽고 있다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 6: [{'단어': 'day', '단어 뜻': '날', '품사': '', '예문': 'Do you like rainy days?', '예문 뜻': '너는 비 오는 날을 좋아하니?'}, {'단어': 'place', '단어 뜻': '장소', '품사': '', '예문': "It's a good place for a picnic.", '예문 뜻': '그곳은 소풍을 가기 좋은 장소이다.'}, {'단어': 'deep', '단어 뜻': '깊은', '품사': '', '예문': 'Don’t swim in deep water.', '예문 뜻': '깊은 물 속에서 수영하지 마라.'}, {'단어': 'sing', '단어 뜻': '노래하다', '품사': '', '예문': 'The birds are singing in the tree.', '예문 뜻': '새들이 나무에서 노래하고 있다.'}, {'단어': 'another', '단어 뜻': '다른', '품사': '', '예문': 'Give me another spoon, please.', '예문 뜻': '다른 숟가락을 주세요.'}, {'단어': 'musical', '단어 뜻': '뮤지컬', '품사': '', '예문': 'The musical was sad.', '예문 뜻': '그 뮤지컬은 슬펐다.'}, {'단어': 'actress', '단어 뜻': '여배우', '품사': '', '예문': 'Is the actress kind?', '예문 뜻': '그 여배우는 친절하니?'}, {'단어': 'welcome', '단어 뜻': '환영합니다, 환영\n해', '품사': '', '예문': 'Welcome to my birthday party!', '예문 뜻': '그 여배우는 친절하니?'}]
# Parsed data for ./pdf_words/fly1.pdf page 7: [{'단어': 'first', '단어 뜻': '첫 번째의', '품사': '', '예문': 'It was her first birthday party.', '예문 뜻': '그것은 그녀의 첫 번째 생일 파티였다.'}, {'단어': 'boring', '단어 뜻': '지루한', '품사': '', '예문': 'This book is boring.', '예문 뜻': '이 책은 지루하다.'}, {'단어': 'find', '단어 뜻': '찾다', '품사': '', '예문': 'Did you find the eraser?', '예문 뜻': '너는 그 지우개를 찾았니?'}, {'단어': 'boots', '단어 뜻': '부츠', '품사': '', '예문': 'My boots are blue.', '예문 뜻': '내 부츠는 파란색이다.'}, {'단어': 'hear', '단어 뜻': '듣다', '품사': '', '예문': 'Can you hear me?', '예문 뜻': '내 말이 들리니?'}, {'단어': 'but', '단어 뜻': '하지만', '품사': '', '예문': "I'm short but my sister is tall.", '예문 뜻': '나는 키가 작지만 우리 언니는 키가 크다.'}, {'단어': 'fun', '단어 뜻': '재미있는', '품사': '', '예문': 'Riding a bike is fun.', '예문 뜻': '자전거 타는 것은 재미있다.'}, {'단어': 'and', '단어 뜻': '~와', '품사': '', '예문': 'Amy likes oranges and bananas.', '예문 뜻': '에이미는 오렌지와 바나나를 좋아한다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 8: [{'단어': 'problem', '단어 뜻': '문제', '품사': '', '예문': 'What is the problem?', '예문 뜻': '문제가 뭐니?'}, {'단어': 'woman', '단어 뜻': '여자', '품사': '', '예문': 'The woman found my key.', '예문 뜻': '그 여자가 내 열쇠를 찾았다.'}, {'단어': 'beautiful', '단어 뜻': '아름다운', '품사': '', '예문': 'These flowers are beautiful.', '예문 뜻': '이 꽃들은 아름답다.'}, {'단어': 'feel', '단어 뜻': '~한 기분이 들다', '품사': '', '예문': 'I feel happy today.', '예문 뜻': '나는 오늘 행복한 기분이 든다.'}, {'단어': 'street', '단어 뜻': '거리', '품사': '', '예문': 'She was walking on the street.', '예문 뜻': '그녀는 거리를 걷고 있었다.'}, {'단어': 'hat', '단어 뜻': '모자', '품사': '', '예문': 'Where is my hat?', '예문 뜻': '내 모자가 어디에 있니?'}, {'단어': 'clothes', '단어 뜻': '옷', '품사': '', '예문': 'Tony bought new clothes today.', '예문 뜻': '토니는 오늘 새 옷을 샀다.'}, {'단어': 'wear', '단어 뜻': '입다', '품사': '', '예문': 'Kate doesn’t wear a skirt.', '예문 뜻': '케이트는 치마를 입지 않는다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 9: [{'단어': 'computer', '단어 뜻': '컴퓨터', '품사': '', '예문': 'Can you use a computer?', '예문 뜻': '너는 컴퓨터를 사용할 수 있니?'}, {'단어': 'school', '단어 뜻': '학교', '품사': '', '예문': 'I go to school at 8.', '예문 뜻': '나는 여덟 시에 학교에 간다.'}, {'단어': 'small', '단어 뜻': '작은', '품사': '', '예문': 'Jane is making a small doll.', '예문 뜻': '제인은 작은 인형을 만들고 있다.'}, {'단어': 'news', '단어 뜻': '소식, 뉴스', '품사': '', '예문': "That's great news.", '예문 뜻': '그것은 좋은 소식이구나.'}, {'단어': 'week', '단어 뜻': '주, 일주일', '품사': '', '예문': 'A week has seven days.', '예문 뜻': '일주일은 7일이다.'}, {'단어': 'difficult', '단어 뜻': '어려운', '품사': '', '예문': 'The math test was very difficult.', '예문 뜻': '수학 시험은 매우 어려웠다.'}, {'단어': 'answer', '단어 뜻': '답, 정답', '품사': '', '예문': 'Do you know the answer?', '예문 뜻': '너는 정답을 아니?'}, {'단어': 'time', '단어 뜻': '시간', '품사': '', '예문': "We don't have much time.", '예문 뜻': '우리는 시간이 많지 않다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 10: [{'단어': 'anything', '단어 뜻': '무엇이든', '품사': '', '예문': 'I can do anything for you.', '예문 뜻': '나는 너를 위해 무엇이든 할 수 있어.'}, {'단어': 'autumn', '단어 뜻': '가을', '품사': '', '예문': 'I read many books in autumn.', '예문 뜻': '나는 가을에 책을 많이 읽는다.'}, {'단어': 'when', '단어 뜻': '언제', '품사': '', '예문': 'When is your birthday?', '예문 뜻': '네 생일은 언제니?'}, {'단어': 'ticket', '단어 뜻': '표', '품사': '', '예문': 'Did you buy the ticket?', '예문 뜻': '너는 표를 샀니?'}, {'단어': 'stay', '단어 뜻': '지내다, 머무르다', '품사': '', '예문': 'He stayed at the hotel for two days.', '예문 뜻': '그는 이틀 동안 그 호텔에서 머물렀다.'}, {'단어': 'circle', '단어 뜻': '동그라미', '품사': '', '예문': 'Draw a circle on the paper.', '예문 뜻': '종이 위에 동그라미를 그려라.'}, {'단어': 'dress', '단어 뜻': '드레스', '품사': '', '예문': 'Do you have a long dress?', '예문 뜻': '너는 긴 드레스를 가지고 있니?'}, {'단어': 'November', '단어 뜻': '11월', '품사': '', '예문': 'The school festival is in November.', '예문 뜻': '학교 축제는 11월에 있다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 11: [{'단어': 'visit', '단어 뜻': '방문하다', '품사': '', '예문': 'Sam will visit Ulsan next week.', '예문 뜻': '샘은 다음 주에 울산을 방문할 것이다.'}, {'단어': 'word', '단어 뜻': '단어', '품사': '', '예문': 'Write the word on the blackboard.', '예문 뜻': '칠판에 단어를 써 봐.'}, {'단어': 'spell', '단어 뜻': '철자를 쓰다', '품사': '', '예문': 'How do you spell your name?', '예문 뜻': '네 이름은 철자를 어떻게 쓰니?'}, {'단어': 'classroom', '단어 뜻': '교실', '품사': '', '예문': 'There are classrooms on the fourth floor.', '예문 뜻': '4층에 교실이 있다.'}, {'단어': 'after', '단어 뜻': '~ 후에', '품사': '', '예문': 'She helped her mom after dinner.', '예문 뜻': '그녀는 저녁 식사 후에 엄마를 도왔다.'}, {'단어': 'scold', '단어 뜻': '야단치다', '품사': '', '예문': 'The teacher is scolding Jake.', '예문 뜻': '선생님이 제이크를 야단치고 계신다.'}, {'단어': 'live', '단어 뜻': '살다', '품사': '', '예문': 'My uncle lives in Busan.', '예문 뜻': '우리 삼촌은 부산에 사신다.'}, {'단어': 'India', '단어 뜻': '인도', '품사': '', '예문': 'Is Maria from India?', '예문 뜻': '마리아는 인도에서 왔니?'}]
# Parsed data for ./pdf_words/fly1.pdf page 12: [{'단어': 'pilot', '단어 뜻': '조종사', '품사': '', '예문': 'My uncle was a pilot.', '예문 뜻': '우리 삼촌은 조종사이셨다.'}, {'단어': 'soon', '단어 뜻': '곧, 머지않아', '품사': '', '예문': 'The bus will come soon.', '예문 뜻': '버스가 곧 올 것이다.'}, {'단어': 'spaceship', '단어 뜻': '우주선', '품사': '', '예문': 'We can travel by spaceship.', '예문 뜻': '우리는 우주선을 타고 여행할 수 있다.'}, {'단어': 'air', '단어 뜻': '공기', '품사': '', '예문': 'Is the air cold and dry in winter?', '예문 뜻': '겨울에 공기가 차갑고 건조하니?'}, {'단어': 'morning', '단어 뜻': '아침', '품사': '', '예문': 'I get up at 7 in the morning.', '예문 뜻': '나는 아침 일곱 시에 일어난다.'}, {'단어': 'wife', '단어 뜻': '아내', '품사': '', '예문': 'The farmer and his wife had an ox.', '예문 뜻': '농부와 그의 아내는 소 한 마리를 가지고 있었다.'}, {'단어': 'April', '단어 뜻': '4월', '품사': '', '예문': 'Tony’s birthday is in April.', '예문 뜻': '토니의 생일은 4월이다.'}, {'단어': 'earth', '단어 뜻': '지구', '품사': '', '예문': 'The earth is getting warmer.', '예문 뜻': '지구가 더 따뜻해지고 있다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 13: [{'단어': 'speech', '단어 뜻': '연설, 웅변', '품사': '', '예문': 'Did you understand his speech?', '예문 뜻': '너는 그의 연설을 이해했니?'}, {'단어': 'contest', '단어 뜻': '대회', '품사': '', '예문': 'A fishing contest is interesting.', '예문 뜻': '낚시 대회는 흥미롭다.'}, {'단어': 'bus', '단어 뜻': '버스', '품사': '', '예문': 'We came home by bus.', '예문 뜻': '우리는 버스를 타고 집에 왔다.'}, {'단어': 'seat', '단어 뜻': '자리', '품사': '', '예문': 'Is this your seat?', '예문 뜻': '이곳은 네 자리니?'}, {'단어': 'stand up', '단어 뜻': '일어서다', '품사': '', '예문': 'Stand up, please.', '예문 뜻': '일어서 주세요.'}, {'단어': 'sit', '단어 뜻': '앉다', '품사': '', '예문': 'Don’t sit on the wet bench.', '예문 뜻': '젖은 벤치에 앉지 마.'}, {'단어': 'police', '단어 뜻': '경찰', '품사': '', '예문': 'The police asked my name.', '예문 뜻': '경찰이 내 이름을 물어 보았다.'}, {'단어': 'say', '단어 뜻': '말하다', '품사': '', '예문': 'What did Tony say?', '예문 뜻': '토니가 뭐라고 말했니?'}]
# Parsed data for ./pdf_words/fly1.pdf page 14: [{'단어': 'drop', '단어 뜻': '떨어뜨리다', '품사': '', '예문': 'Did you drop the vase?', '예문 뜻': '네가 꽃병을 떨어뜨렸니?'}, {'단어': 'fire', '단어 뜻': '불', '품사': '', '예문': 'The fire started in the kitchen.', '예문 뜻': '그 불은 부엌에서 시작되었다.'}, {'단어': 'rock', '단어 뜻': '바위', '품사': '', '예문': 'Falling rocks are dangerous.', '예문 뜻': '떨어지는 바위는 위험하다.'}, {'단어': 'rich', '단어 뜻': '부유한', '품사': '', '예문': 'The man was rich but not happy.', '예문 뜻': '그 남자는 부유했지만 행복하지 않았다.'}, {'단어': 'strong', '단어 뜻': '강한', '품사': '', '예문': 'The wind is not strong today.', '예문 뜻': '오늘은 바람이 강하지 않다.'}, {'단어': 'bomb', '단어 뜻': '폭탄', '품사': '', '예문': 'People are afraid of bombs.', '예문 뜻': '사람들은 폭탄을 두려워한다.'}, {'단어': 'tell', '단어 뜻': '말하다', '품사': '', '예문': 'Please tell us the truth.', '예문 뜻': '우리에게 진실을 말해 주세요.'}, {'단어': 'both', '단어 뜻': '둘 다', '품사': '', '예문': 'I miss them both.', '예문 뜻': '나는 그들이 둘 다 그립다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 15: [{'단어': 'concert', '단어 뜻': '연주회', '품사': '', '예문': 'We are going to a concert.', '예문 뜻': '우리는 연주회에 가고 있다.'}, {'단어': 'ear', '단어 뜻': '귀', '품사': '', '예문': 'His ears are small.', '예문 뜻': '그의 귀는 작다.'}, {'단어': 'tired', '단어 뜻': '피곤한', '품사': '', '예문': 'Sam was hungry and tired.', '예문 뜻': '샘은 배고프고 피곤했다.'}, {'단어': 'pain', '단어 뜻': '고통', '품사': '', '예문': 'Do you feel pain in your legs?', '예문 뜻': '당신의 다리에 고통이 있습니까?'}, {'단어': 'music', '단어 뜻': '음악', '품사': '', '예문': 'Does Chris like music?', '예문 뜻': '크리스는 음악을 좋아하니?'}, {'단어': 'excellent', '단어 뜻': '훌륭한', '품사': '', '예문': 'Mom’s cake was excellent.', '예문 뜻': '엄마의 케이크는 훌륭했다.'}, {'단어': 'end', '단어 뜻': '끝나다', '품사': '', '예문': 'The game ends at five.', '예문 뜻': '그 시합은 다섯 시에 끝난다.'}, {'단어': 'art', '단어 뜻': '예술', '품사': '', '예문': 'French people love art.', '예문 뜻': '프랑스 사람들은 예술을 사랑한다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 16: [{'단어': 'question', '단어 뜻': '질문', '품사': '', '예문': 'Do you have a question?', '예문 뜻': '너는 질문이 있니?'}, {'단어': 'moon', '단어 뜻': '달', '품사': '', '예문': 'The moon is round.', '예문 뜻': '달이 동그랗다.'}, {'단어': 'hen', '단어 뜻': '암탉', '품사': '', '예문': 'My grandpa has many hens.', '예문 뜻': '우리 할아버지는 암탉을 많이 가지고 계신다.'}, {'단어': 'egg', '단어 뜻': '달걀', '품사': '', '예문': 'She needs two eggs.', '예문 뜻': '그녀는 달걀 두 개가 필요하다.'}, {'단어': 'where', '단어 뜻': '어디에', '품사': '', '예문': 'Where do you live?', '예문 뜻': '너는 어디에 사니?'}, {'단어': 'do', '단어 뜻': '하다', '품사': '', '예문': 'Kate is doing her homework.', '예문 뜻': '케이트는 숙제를 하고 있다.'}, {'단어': 'quiet', '단어 뜻': '조용한', '품사': '', '예문': 'Be quiet.', '예문 뜻': '조용히 해.'}, {'단어': 'cute', '단어 뜻': '귀여운', '품사': '', '예문': 'My brother is cute.', '예문 뜻': '내 남동생은 귀엽다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 17: [{'단어': 'blind', '단어 뜻': '눈이 먼', '품사': '', '예문': 'The dog is helping the blind man.', '예문 뜻': '그 개가 눈이 먼 남자를 돕고 있다.'}, {'단어': 'palm', '단어 뜻': '손바닥', '품사': '', '예문': 'He wrote something on my palm.', '예문 뜻': '그는 내 손바닥 위에 무엇인가를 썼다.'}, {'단어': 'lip', '단어 뜻': '입술', '품사': '', '예문': 'Which animals have lips?', '예문 뜻': '어떤 동물이 입술이 있니?'}, {'단어': 'effort', '단어 뜻': '노력', '품사': '', '예문': 'She put more effort into her studies.', '예문 뜻': '그녀는 공부에 더 많은 노력을 기울였다.'}, {'단어': 'today', '단어 뜻': '오늘', '품사': '', '예문': 'What day is it today?', '예문 뜻': '오늘이 무슨 요일이니?'}, {'단어': 'magazine', '단어 뜻': '잡지', '품사': '', '예문': 'I saw her picture in the magazine.', '예문 뜻': '나는 잡지에서 그녀의 사진을 보았다.'}, {'단어': 'girl', '단어 뜻': '소녀', '품사': '', '예문': 'Mary is a smart girl.', '예문 뜻': '메리는 영리한 소녀다.'}, {'단어': 'remember', '단어 뜻': '기억하다', '품사': '', '예문': 'I don’t remember her phone number.', '예문 뜻': '나는 그녀의 전화번호가 기억나지 않는다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 18: [{'단어': 'honest', '단어 뜻': '솔직한', '품사': '', '예문': 'Bill is an honest boy.', '예문 뜻': '빌은 솔직한 소년이다.'}, {'단어': 'reporter', '단어 뜻': '기자', '품사': '', '예문': 'The reporter met a famous artist.', '예문 뜻': '그 기자는 유명한 화가를 만났다.'}, {'단어': 'television', '단어 뜻': '텔레비전', '품사': '', '예문': 'How long do you watch television a day?', '예문 뜻': '너는 하루에 텔레비전을 얼마나 오래 보니?'}, {'단어': 'chance', '단어 뜻': '기회', '품사': '', '예문': 'Don’t miss this chance.', '예문 뜻': '이 기회를 놓치지 마.'}, {'단어': 'baseball', '단어 뜻': '야구', '품사': '', '예문': 'Do they play baseball after school?', '예문 뜻': '그들은 방과 후에 야구를 하니?'}, {'단어': 'congratulate', '단어 뜻': '축하하다', '품사': '', '예문': 'We congratulated Jack on his new job.', '예문 뜻': '우리는 잭이 새로운 직업을 갖게 된 것을 축하했다.'}, {'단어': 'thank', '단어 뜻': '(~ 고마워\n하다', '품사': '에게', '예문': 'Thank you for the present.', '예문 뜻': '선물 고마워'}, {'단어': 'staff', '단어 뜻': '직원', '품사': '', '예문': 'The restaurant staff is kind.', '예문 뜻': '그 음식점 직원은 친절하다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 19: [{'단어': 'what', '단어 뜻': '무엇', '품사': '', '예문': 'What does Harry like?', '예문 뜻': '해리는 무엇을 좋아하니?'}, {'단어': 'again', '단어 뜻': '다시', '품사': '', '예문': 'See you again soon.', '예문 뜻': '곧 다시 봐.'}, {'단어': 'buy', '단어 뜻': '사다', '품사': '', '예문': 'Mom will buy some cheese.', '예문 뜻': '엄마는 치즈를 조금 사실 것이다.'}, {'단어': 'kid', '단어 뜻': '아이', '품사': '', '예문': 'The kid is cute.', '예문 뜻': '그 아이는 귀엽다.'}, {'단어': 'bottle', '단어 뜻': '병', '품사': '', '예문': 'Did you open this bottle?', '예문 뜻': '네가 이 병을 열었니?'}, {'단어': 'thirsty', '단어 뜻': '목마른', '품사': '', '예문': 'The horses were very thirsty.', '예문 뜻': '그 말들은 매우 목이 말랐다.'}, {'단어': 'expensive', '단어 뜻': '비싼', '품사': '', '예문': 'Is that watch expensive?', '예문 뜻': '저 손목시계는 비싸니?'}, {'단어': 'store', '단어 뜻': '가게, 상점', '품사': '', '예문': 'This store sells computers', '예문 뜻': '이 가게는 컴퓨터를 판다. .'}]
# Parsed data for ./pdf_words/fly1.pdf page 20: [{'단어': 'arm', '단어 뜻': '팔', '품사': '', '예문': 'His arms are strong.', '예문 뜻': '그의 팔은 튼튼하다.'}, {'단어': 'ill', '단어 뜻': '아픈', '품사': '', '예문': 'My grandma is ill.', '예문 뜻': '우리 할머니는 아프시다.'}, {'단어': 'cook', '단어 뜻': '요리하다', '품사': '', '예문': 'Who is cooking dinner?', '예문 뜻': '누가 저녁을 요리하고 있니?'}, {'단어': 'hurry', '단어 뜻': '서두르다', '품사': '', '예문': 'Hurry up, Jake.', '예문 뜻': '서둘러라, 제이크.'}, {'단어': 'count', '단어 뜻': '세다', '품사': '', '예문': 'She counted the beds.', '예문 뜻': '그녀는 침대 개수를 세었다.'}, {'단어': 'bread', '단어 뜻': '빵', '품사': '', '예문': 'The bread smells good.', '예문 뜻': '빵 냄새가 좋다.'}, {'단어': 'meat', '단어 뜻': '고기', '품사': '', '예문': 'Do you sell meat?', '예문 뜻': '고기를 파세요?'}, {'단어': 'angel', '단어 뜻': '천사', '품사': '', '예문': 'Angels have wings.', '예문 뜻': '천사는 날개를 가지고 있다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 21: [{'단어': 'believe', '단어 뜻': '믿다', '품사': '', '예문': "I can't believe the news.", '예문 뜻': '나는 그 소식을 믿을 수 없다.'}, {'단어': 'curious', '단어 뜻': '궁금한', '품사': '', '예문': 'Are you curious about space?', '예문 뜻': '너는 우주에 대해 궁금하니?'}, {'단어': 'cloth', '단어 뜻': '천', '품사': '', '예문': 'Cover the basket with a wet cloth.', '예문 뜻': '젖은 천으로 바구니를 덮어라.'}, {'단어': 'without', '단어 뜻': '~ 없이', '품사': '', '예문': 'Dad went to work without his bag.', '예문 뜻': '아빠는 가방 없이 회사에 가셨다.'}, {'단어': 'kite', '단어 뜻': '연', '품사': '', '예문': 'Flying a kite is exciting.', '예문 뜻': '연을 날리는 것은 신나.'}, {'단어': 'magic', '단어 뜻': '마술', '품사': '', '예문': 'Daniel showed us some magic tricks.', '예문 뜻': '다니엘은 우리에게 마술 묘기를 보여주었다.'}, {'단어': 'corn', '단어 뜻': '옥수수', '품사': '', '예문': 'Can you make corn soup?', '예문 뜻': '너는 옥수수 수프를 만들 수 있니?'}, {'단어': 'amazing', '단어 뜻': '놀라운', '품사': '', '예문': 'The night view is amazing from the building.', '예문 뜻': '그 빌딩의 야경은 놀랍다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 22: [{'단어': 'singer', '단어 뜻': '가수', '품사': '', '예문': 'Do you know the singer?', '예문 뜻': '너는 그 가수를 아니?'}, {'단어': 'stage', '단어 뜻': '무대', '품사': '', '예문': 'Get off the stage!', '예문 뜻': '무대에서 내려와!'}, {'단어': 'voice', '단어 뜻': '목소리', '품사': '', '예문': "I can't hear your voice.", '예문 뜻': '나는 네 목소리를 들을 수 없다.'}, {'단어': 'worry', '단어 뜻': '걱정하다', '품사': '', '예문': 'Don’t worry, Dad.', '예문 뜻': '아빠, 걱정하지 마세요.'}, {'단어': 'man', '단어 뜻': '남자', '품사': '', '예문': 'The man is fixing his car.', '예문 뜻': '그 남자는 그의 차를 고치고 있다.'}, {'단어': 'best', '단어 뜻': '최고의', '품사': '', '예문': 'Who is the best actor?', '예문 뜻': '누가 최고의 배우이니?'}, {'단어': 'coin', '단어 뜻': '동전', '품사': '', '예문': 'Jenny needs some coins.', '예문 뜻': '제니는 동전이 좀 필요하다.'}, {'단어': 'gold', '단어 뜻': '황금, 금', '품사': '', '예문': 'Time is gold.', '예문 뜻': '시간은 금이다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 23: [{'단어': 'sleepy', '단어 뜻': '졸린', '품사': '', '예문': 'I always feel sleepy after lunch.', '예문 뜻': '나는 점심식사 후에 항상 졸리다.'}, {'단어': 'number', '단어 뜻': '숫자', '품사': '', '예문': 'Can you read the numbers in English?', '예문 뜻': '너는 영어로 그 숫자를 읽을 수 있니?'}, {'단어': 'add', '단어 뜻': '더하다', '품사': '', '예문': 'Add 9 to the number.', '예문 뜻': '그 숫자에 9를 더해라'}, {'단어': 'solve', '단어 뜻': '풀다', '품사': '', '예문': 'She finally solved the puzzle.', '예문 뜻': '그녀는 마침내 퍼즐을 풀었다.'}, {'단어': 'explain', '단어 뜻': '설명하다', '품사': '', '예문': 'I’ll explain the rules of this game.', '예문 뜻': '내가 이 게임의 규칙을 설명해 줄게.'}, {'단어': 'still', '단어 뜻': '여전히', '품사': '', '예문': 'Are you still hungry, Jim?', '예문 뜻': '너는 여전히 배가 고프니, 짐?'}, {'단어': 'simple', '단어 뜻': '간단한', '품사': '', '예문': 'Cooking spaghetti is simple.', '예문 뜻': '스파게티를 요리하는 것은 간단하다.'}, {'단어': 'talent', '단어 뜻': '재능', '품사': '', '예문': 'He has a talent for music.', '예문 뜻': '그는 음악에 재능이 있다.'}]
# Parsed data for ./pdf_words/fly1.pdf page 24: [{'단어': 'against', '단어 뜻': '~에 반대하여', '품사': '', '예문': 'She is against wearing a fur coat.', '예문 뜻': '그녀는 모피코트를 입는 것에 반대한다.'}, {'단어': 'island', '단어 뜻': '섬', '품사': '', '예문': 'Nobody lived on the island.', '예문 뜻': '그 섬에 아무도 살지 않았다.'}, {'단어': 'meal', '단어 뜻': '식사', '품사': '', '예문': 'Do you eat kimchi at every meal?', '예문 뜻': '너는 식사 때마다 김치를 먹니?'}, {'단어': 'once', '단어 뜻': '한 번', '품사': '', '예문': 'My family goes camping once a month.', '예문 뜻': '우리 가족은 한 달에 한 번 캠핑하러 간다.'}, {'단어': 'calendar', '단어 뜻': '달력', '품사': '', '예문': 'He marked her birthday on the calendar.', '예문 뜻': '그는 달력에 그녀의 생일을 표시했다.'}, {'단어': 'waste', '단어 뜻': '낭비하다', '품사': '', '예문': 'Don’t waste your time.', '예문 뜻': '네 시간을 낭비하지 마라.'}, {'단어': 'vegetable', '단어 뜻': '채소', '품사': '', '예문': 'Are tomatoes vegetables?', '예문 뜻': '토마토는 채소니?'}, {'단어': 'history', '단어 뜻': '역사', '품사': '', '예문': 'Sue learned American history today.', '예문 뜻': '수는 오늘 미국 역사를 배웠다.'}]
# Parsed data for ./pdf_words/fly2.pdf page 1: [{'단어': 'catch', '단어 뜻': '잡다', '품사': '동사', '예문': 'I will catch the ball.', '예문 뜻': '내가 그 공을 잡을 거야.'}, {'단어': 'drive', '단어 뜻': '운전하다', '품사': '동사', '예문': 'I am driving a car.', '예문 뜻': '나는 운전 중이야.'}, {'단어': 'enter', '단어 뜻': '들어가다', '품사': '동사', '예문': 'I entered the room.', '예문 뜻': '나는 그 방에 들어갔어.'}, {'단어': 'health', '단어 뜻': '건강', '품사': '명사', '예문': 'The health club is good for health.', '예문 뜻': '헬스클럽에 다니면 건강해져.'}, {'단어': 'hit', '단어 뜻': '치다', '품사': '동사', '예문': 'I hit the ball.', '예문 뜻': '내가 그 공을 쳤어.'}, {'단어': 'reply', '단어 뜻': '답변하다', '품사': '동사', '예문': 'I replied to his reply.', '예문 뜻': '나는 그의 댓글에 답변을 달았어.'}, {'단어': 'variety', '단어 뜻': '여러 가지', '품사': '명사', '예문': 'There are a variety of shows.', '예문 뜻': '여러 가지 쇼가 있어.'}, {'단어': 'wait', '단어 뜻': '기다리다', '품사': '동사', '예문': 'I’m waiting for the customer.', '예문 뜻': '나는 손님을 기다리고 있어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 2: [{'단어': 'blind', '단어 뜻': '눈이 먼', '품사': '형용사', '예문': 'He is blind.', '예문 뜻': '그는 앞이 안 보여.'}, {'단어': 'count', '단어 뜻': '세다', '품사': '동사', '예문': 'I’m counting numbers.', '예문 뜻': '숫자를 세고 있어.'}, {'단어': 'cover', '단어 뜻': '덮다, 가리\n다', '품사': '동사', '예문': 'Cover very boby!', '예문 뜻': '몸을 가려!'}, {'단어': 'flat', '단어 뜻': '납작한', '품사': '형용사', '예문': 'The shoes are flat.', '예문 뜻': '그 신발은 납작해.'}, {'단어': 'guide', '단어 뜻': '안내하다', '품사': '동사', '예문': 'The guide is guiding us.', '예문 뜻': '안내인이 우리를 안내하고 있어.'}, {'단어': 'record', '단어 뜻': '기록하다', '품사': '동사', '예문': 'I’ve recorded it on the recorder.', '예문 뜻': '그것을 녹음기에 기록했어.'}, {'단어': 'sink', '단어 뜻': '가라앉다', '품사': '동사', '예문': 'A spoon is sinking.', '예문 뜻': '숟가락이 가라앉고 있어.'}, {'단어': 'wide', '단어 뜻': '넓은', '품사': '동사', '예문': 'The TV is wide.', '예문 뜻': '그 TV는 넓어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 3: [{'단어': 'boil', '단어 뜻': '끓다', '품사': '동사', '예문': 'Boil the water.', '예문 뜻': '물을 끓여.'}, {'단어': 'chew', '단어 뜻': '씹다', '품사': '동사', '예문': 'My dog has chewed my bag.', '예문 뜻': '우리 개가 내 가방을 씹어 놨어.'}, {'단어': 'fill', '단어 뜻': '채우다', '품사': '동사', '예문': 'Fill the glass.', '예문 뜻': '잔을 채워 줘.'}, {'단어': 'fold', '단어 뜻': '접다', '품사': '동사', '예문': 'Fold the paper like this.', '예문 뜻': '이렇게 종이를 접어.'}, {'단어': 'gentle', '단어 뜻': '부드러\n운', '품사': '형용사', '예문': 'The gentleman is gentle.', '예문 뜻': '그 신사는 부드러워.'}, {'단어': 'shake', '단어 뜻': '흔들다', '품사': '동사', '예문': 'I’m shaking a shake.', '예문 뜻': '나는 셰이크를 흔들고 있어.'}, {'단어': 'tie', '단어 뜻': '매다', '품사': '동사', '예문': 'I tied the necktie.', '예문 뜻': '나는 넥타이를 맸어.'}, {'단어': 'wave', '단어 뜻': '흔들다', '품사': '동사', '예문': 'Her hair is waving in the wind.', '예문 뜻': '그녀의 머리가 바람에 흔들리고 있어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 4: [{'단어': 'explore', '단어 뜻': '탐험하다', '품사': '동사', '예문': 'Let’s explore the online world!', '예문 뜻': '인터넷 세상을 탐험하자!'}, {'단어': 'highlight', '단어 뜻': '강조하다', '품사': '동사', '예문': 'Highlight the word.', '예문 뜻': '그 단어를 강조해.'}, {'단어': 'lead', '단어 뜻': '이끌다', '품사': '동사', '예문': 'I’m leading my class.', '예문 뜻': '나는 우리 반을 이끌고 있어.'}, {'단어': 'lift', '단어 뜻': '들어 올리\n다', '품사': '동사', '예문': 'The lift is lifting us.', '예문 뜻': '리프트가 우리를 들어 올리고 있어.'}, {'단어': 'quick', '단어 뜻': '빠른', '품사': '형용사', '예문': 'The service is quick.', '예문 뜻': '그 서비스는 빨라.'}, {'단어': 'shut', '단어 뜻': '닫다', '품사': '동사', '예문': 'I’m shutting the shutters.', '예문 뜻': '나는 셔터를 닫고 있어.'}, {'단어': 'suit', '단어 뜻': '어울리다', '품사': '동사', '예문': 'The black suit suits me.', '예문 뜻': '나는 검은 정장이 어울려.'}, {'단어': 'wrap', '단어 뜻': '포장하다', '품사': '동사', '예문': 'I’m wrapping the food.', '예문 뜻': '나는 음식을 포장하고 있어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 5: [{'단어': 'bake', '단어 뜻': '굽다', '품사': '동사', '예문': 'I’m baking some bread.', '예문 뜻': '나는 빵을 굽고 있어.'}, {'단어': 'boring', '단어 뜻': '지루한', '품사': '형용사', '예문': 'Bowling is boring.', '예문 뜻': '볼링은 지루해.'}, {'단어': 'bring', '단어 뜻': '가지고 오\n다', '품사': '동사', '예문': 'He is bringing a ring.', '예문 뜻': '그는 반지를 가져오고 있어.'}, {'단어': 'desert', '단어 뜻': '사막', '품사': '명사', '예문': 'I’m eating in the desert.', '예문 뜻': '나는 사막에서 먹고 있어.'}, {'단어': 'dig', '단어 뜻': '파다', '품사': '동사', '예문': 'A pig is digging in the garden.', '예문 뜻': '돼지가 정원에서 땅을 파고 있어.'}, {'단어': 'feed', '단어 뜻': '먹이를 주\n다', '품사': '동사', '예문': 'I’m feeding the monkeys.', '예문 뜻': '나는 원숭이들에게 먹이를 주고 있어.'}, {'단어': 'leave', '단어 뜻': '떠나다', '품사': '동사', '예문': 'I’m leaving now.', '예문 뜻': '나는 지금 떠나.'}, {'단어': 'seek', '단어 뜻': '찾다', '품사': '동사', '예문': 'I’m seeking the K.', '예문 뜻': '나는 K를 찾고 있어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 6: [{'단어': 'alarm', '단어 뜻': '깜짝 놀라\n게 하다', '품사': '동사', '예문': 'The alarm clock alarmed me.', '예문 뜻': '알람 시계 때문에 깜짝 놀랐어.'}, {'단어': 'burn', '단어 뜻': '타다', '품사': '동사', '예문': 'The bun is burning.', '예문 뜻': '빵이 타고 있어.'}, {'단어': 'candle', '단어 뜻': '초', '품사': '명사', '예문': 'This candle is cheap.', '예문 뜻': '이 초는 가격이 싸.'}, {'단어': 'faint', '단어 뜻': '희미한', '품사': '형용사', '예문': 'The paint is faint.', '예문 뜻': '페인트가 희미해.'}, {'단어': 'handle', '단어 뜻': '다루다', '품사': '동사', '예문': 'You handle the steering wheel well.', '예문 뜻': '너 핸들 잘 다루네.'}, {'단어': 'neat', '단어 뜻': '깔끔한', '품사': '형용사', '예문': 'Her knit top looks neat.', '예문 뜻': '그녀의 니트는 깔끔해 보여.'}, {'단어': 'pile', '단어 뜻': '더미', '품사': '명사', '예문': 'There are a pile of files.', '예문 뜻': '파일이 한 더미 있어.'}, {'단어': 'remember', '단어 뜻': '기억하다', '품사': '동사', '예문': 'Do you remember the members?', '예문 뜻': '그 맴버들 기억나니?'}]
# Parsed data for ./pdf_words/fly2.pdf page 7: [{'단어': 'arrange', '단어 뜻': '정리하다', '품사': '동사', '예문': 'We arranged the oranges.', '예문 뜻': '우리 오렌지를 정리했어.'}, {'단어': 'bother', '단어 뜻': '괴롭히다', '품사': '동사', '예문': 'My brothers bother me.', '예문 뜻': '내 남동생들이 나를 귀찮게 해.'}, {'단어': 'broad', '단어 뜻': '넓은', '품사': '형용사', '예문': 'It’s a broad road.', '예문 뜻': '그것은 넓은 길이야.'}, {'단어': 'build', '단어 뜻': '짓다', '품사': '동사', '예문': 'I’m building a building.', '예문 뜻': '나는 빌딩을 짓고 있어.'}, {'단어': 'slippery', '단어 뜻': '미끄러\n운', '품사': '형용사', '예문': 'These slippers are slippery.', '예문 뜻': '이 슬리퍼는 미끄러워.'}, {'단어': 'spot', '단어 뜻': '점', '품사': '명사', '예문': 'There is a spot on the pot.', '예문 뜻': '주전자에 점이 있어.'}, {'단어': 'sweat', '단어 뜻': '땀 흘리다', '품사': '동사', '예문': 'Sweaters make me sweat.', '예문 뜻': '스웨터를 입으면 땀이 나.'}, {'단어': 'wipe', '단어 뜻': '닦다', '품사': '동사', '예문': 'She is wiping the window.', '예문 뜻': '그녀는 창문을 닦고 있어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 8: [{'단어': 'bend', '단어 뜻': '구부리다', '품사': '동사', '예문': 'I can bend the rubber band.', '예문 뜻': '나는 고무 밴드를 구부릴 수 있어.'}, {'단어': 'bunch', '단어 뜻': '다발', '품사': '명사', '예문': 'There are a bunch of roses.', '예문 뜻': '장미꽃 한 다발이 있어.'}, {'단어': 'damp', '단어 뜻': '축축한', '품사': '형용사', '예문': 'My hair is damp.', '예문 뜻': '내 머리카락이 축축해.'}, {'단어': 'load', '단어 뜻': '짐을 싣다', '품사': '동사', '예문': 'He loaded the handcart.', '예문 뜻': '그는 리어카에 짐을 실었어.'}, {'단어': 'pat', '단어 뜻': '쓰다듬다', '품사': '동사', '예문': 'I’m patting my pets.', '예문 뜻': '나는 애완동물을 쓰다듬고 있어.'}, {'단어': 'scold', '단어 뜻': '혼내다', '품사': '동사', '예문': 'Don’t scold me too coldly.', '예문 뜻': '날 너무 차갑게 혼내지 마.'}, {'단어': 'soak', '단어 뜻': '적시다', '품사': '동사', '예문': 'The soap is soaked.', '예문 뜻': '비누가 젖었어.'}, {'단어': 'terrible', '단어 뜻': '끔찍한', '품사': '형용사', '예문': 'The terror was terrible.', '예문 뜻': '그 테러는 끔찍했어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 9: [{'단어': 'bite', '단어 뜻': '물다', '품사': '동사', '예문': 'She is biting a cookie.', '예문 뜻': '그녀는 쿠키를 물고 있어.'}, {'단어': 'call', '단어 뜻': '부르다, 전\n화하다', '품사': '동사', '예문': 'I’m calling my doctor.', '예문 뜻': '나는 의사를 부를 거야.'}, {'단어': 'contact', '단어 뜻': '연락하다,\n접촉하다', '품사': '동사', '예문': 'He can’t contact anyone.', '예문 뜻': '그는 아무에게도 연락할 수 없어.'}, {'단어': 'fall', '단어 뜻': '떨어지다', '품사': '동사', '예문': 'Leaves are falling.', '예문 뜻': '나뭇잎이 떨어지고 있어.'}, {'단어': 'lie', '단어 뜻': '눕다, 거짓\n말하다', '품사': '동사', '예문': 'I’m lying on the floor.', '예문 뜻': '나는 바닥에 누워 있어.'}, {'단어': 'park', '단어 뜻': '주차하다', '품사': '동사', '예문': 'I parked at the park.', '예문 뜻': '나는 공원에 주차했어.'}, {'단어': 'shoot', '단어 뜻': '쏘다, 발사\n하다', '품사': '동사', '예문': 'I’m shooting at the goal.', '예문 뜻': '나는 골문을 향해 슛을 쏘겠어.'}, {'단어': 'store', '단어 뜻': '저장하다', '품사': '동사', '예문': 'Store goods in the store.', '예문 뜻': '물건을 가게에 저장해.'}]
# Parsed data for ./pdf_words/fly2.pdf page 10: [{'단어': 'bat', '단어 뜻': '방망이', '품사': '명사', '예문': 'I have a big bat.', '예문 뜻': '나는 큰 방망이를 갖고 있어.'}, {'단어': 'correct', '단어 뜻': '맞는', '품사': '형용사', '예문': 'This is the correct answer!', '예문 뜻': '이게 맞는 답이야!'}, {'단어': 'goal', '단어 뜻': '목표, 골', '품사': '명사', '예문': 'My goal is to make a goal!', '예문 뜻': '내 목표는 골을 넣는 거야!'}, {'단어': 'mind', '단어 뜻': '꺼리다', '품사': '동사', '예문': 'Do you mind if I kill this bug?', '예문 뜻': '내가 이 벌레를 죽여도 될까?'}, {'단어': 'order', '단어 뜻': '명령하다', '품사': '동사', '예문': 'I ordered them to line up.', '예문 뜻': '나는 그들에게 줄을 서라고 명령했어.'}, {'단어': 'rest', '단어 뜻': '쉬다', '품사': '동사', '예문': 'I’m resting on the bench.', '예문 뜻': '나는 벤치에 누워서 쉬고 있어.'}, {'단어': 'trace', '단어 뜻': '추적하다', '품사': '동사', '예문': 'Trace the trace he left.', '예문 뜻': '그가 남긴 흔적을 추적해.'}, {'단어': 'train', '단어 뜻': '훈련시키다', '품사': '동사', '예문': 'I train my team.', '예문 뜻': '나는 내 팀을 훈련시켜.'}]
# Parsed data for ./pdf_words/fly2.pdf page 11: [{'단어': 'check', '단어 뜻': '확인하다', '품사': '동사', '예문': 'Check the check!', '예문 뜻': '수표 확인해 봐!'}, {'단어': 'head', '단어 뜻': '향하다', '품사': '동사', '예문': 'He is heading to the right.', '예문 뜻': '그는 오른쪽으로 향하고 있어.'}, {'단어': 'last', '단어 뜻': '계속되다', '품사': '동사', '예문': 'Our friendship will last to the end.', '예문 뜻': '우리의 우정은 마지막까지 계속될 거야.'}, {'단어': 'lock', '단어 뜻': '잠그다', '품사': '동사', '예문': 'You should lock your locker.', '예문 뜻': '사물함을 잠그는 것이 좋아.'}, {'단어': 'march', '단어 뜻': '행진하다', '품사': '동사', '예문': 'The couple is marching.', '예문 뜻': '그 부부는 행진하고 있어.'}, {'단어': 'point', '단어 뜻': '가리키다', '품사': '동사', '예문': 'He is pointing at my face.', '예문 뜻': '그가 내 얼굴을 가리키고 있어.'}, {'단어': 'present', '단어 뜻': '출석한', '품사': '형용사', '예문': 'I was present at the class.', '예문 뜻': '나는 그 수업에 출석했어.'}, {'단어': 'swing', '단어 뜻': '흔들다', '품사': '동사', '예문': 'She is swinging the swing.', '예문 뜻': '그녀는 그네를 흔들고 있어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 12: [{'단어': 'book', '단어 뜻': '예약하다', '품사': '동사', '예문': 'I’d like to book this book.', '예문 뜻': '나는 이 책을 예약하고 싶어요.'}, {'단어': 'chance', '단어 뜻': '우연', '품사': '동사', '예문': 'I saw him by chance.', '예문 뜻': '우연히 그를 봤어.'}, {'단어': 'change', '단어 뜻': '바꾸다', '품사': '동사', '예문': 'May I change my money?', '예문 뜻': '돈 좀 바꿔 주시겠어요?'}, {'단어': 'exercise', '단어 뜻': '운동하다', '품사': '동사', '예문': 'I exercise every day.', '예문 뜻': '나는 매일 운동해.'}, {'단어': 'fine', '단어 뜻': '벌금을 물리다', '품사': '동사', '예문': 'I was fined for parking.', '예문 뜻': '주차 때문에 벌금을 물었어.'}, {'단어': 'match', '단어 뜻': '대결, 성냥', '품사': '명사', '예문': 'He won the match.', '예문 뜻': '그는 그 대결을 이겼어.'}, {'단어': 'ring', '단어 뜻': '울리다', '품사': '동사', '예문': 'The bell is ringing.', '예문 뜻': '종소리가 울리고 있어.'}, {'단어': 'try', '단어 뜻': '시도하다', '품사': '동사', '예문': 'Try Korean food.', '예문 뜻': '한국 음식 한번 먹어 봐.'}]
# Parsed data for ./pdf_words/fly2.pdf page 13: [{'단어': 'bug', '단어 뜻': '괴롭히다', '품사': '동사', '예문': 'Bugs are bugging me.', '예문 뜻': '벌레들이 나를 괴롭히고 있어.'}, {'단어': 'drag', '단어 뜻': '끌다', '품사': '동사', '예문': 'An ant is dragging a petal.', '예문 뜻': '개미 한 마리가 꽃잎을 끌고 가고 있어.'}, {'단어': 'duck', '단어 뜻': '휙 수그리다', '품사': '동사', '예문': 'The duck ducked quickly.', '예문 뜻': '그 오리는 재빨리 머리를 휙 수그렸어.'}, {'단어': 'hop', '단어 뜻': '깡충 뛰다', '품사': '동사', '예문': 'The rabbit is hopping with joy.', '예문 뜻': '그 토끼는 기뻐서 깡충 뛰고 있어.'}, {'단어': 'nap', '단어 뜻': '낮잠을 자다', '품사': '동사', '예문': 'She is napping in the restaurant.', '예문 뜻': '그녀는 식당에서 낮잠을 자고 있어.'}, {'단어': 'pin', '단어 뜻': '꽂다', '품사': '동사', '예문': 'I pinned the note on the wall.', '예문 뜻': '나는 메모를 벽에 꽂았어.'}, {'단어': 'twist', '단어 뜻': '꼬다', '품사': '동사', '예문': 'He is about to twist his legs.', '예문 뜻': '그는 막 다리를 꼬려고 하고 있어.'}, {'단어': 'village', '단어 뜻': '마을', '품사': '명사', '예문': 'There are some villas in the village.', '예문 뜻': '그 마을에는 별장이 좀 있어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 14: [{'단어': 'blush', '단어 뜻': '얼굴을 붉히다', '품사': '동사', '예문': 'I blush when I’m happy.', '예문 뜻': '나는 기쁠 때 얼굴이 빨개져.'}, {'단어': 'cabin', '단어 뜻': '오두막', '품사': '명사', '예문': 'Kevin’s cabin is cozy.', '예문 뜻': 'Kevin의 오두막은 아늑해.'}, {'단어': 'mustache', '단어 뜻': '콧수염', '품사': '명사', '예문': 'He got some mustard on his mustache.', '예문 뜻': '그의 콧수염에 겨자가 묻었어.'}, {'단어': 'poke', '단어 뜻': '쿡 찌르다', '품사': '동사', '예문': 'I poked it with a fork.', '예문 뜻': '나는 그것을 포크로 쿡 찔렀어.'}, {'단어': 'sigh', '단어 뜻': '한숨을 쉬다', '품사': '동사', '예문': 'He sighed at the crowd.', '예문 뜻': '그는 인파 때문에 한숨을 쉬었어.'}, {'단어': 'smoke', '단어 뜻': '연기', '품사': '명사', '예문': 'Smoke is coming out of the grill.', '예문 뜻': '그릴에서 연기가 나고 있어.'}, {'단어': 'stamp', '단어 뜻': '구르다', '품사': '동사', '예문': 'The boy is stamping his foot.', '예문 뜻': '소년이 발을 구르고 있어.'}, {'단어': 'toss', '단어 뜻': '던지다', '품사': '동사', '예문': 'He tossed the toast onto the plate.', '예문 뜻': '그가 토스트를 접시 위로 던졌어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 15: [{'단어': 'dump', '단어 뜻': '버리다', '품사': '동사', '예문': 'The truck is dumping the trash.', '예문 뜻': '트럭이 쓰레기를 버리고 있어.'}, {'단어': 'flee', '단어 뜻': '도망치다', '품사': '동사', '예문': 'She is fleeing from the prison.', '예문 뜻': '그녀는 감옥에서 도망치는 중이야.'}, {'단어': 'float', '단어 뜻': '뜨다', '품사': '동사', '예문': 'A flute is floating on the water.', '예문 뜻': '플루트가 물에 떠 있어.'}, {'단어': 'giggle', '단어 뜻': '낄낄거리다', '품사': '동사', '예문': 'The goggles make me giggle.', '예문 뜻': '그 고글이 나를 낄낄거리게 해.'}, {'단어': 'hairy', '단어 뜻': '털이 많은', '품사': '형용사', '예문': 'The man is hairy.', '예문 뜻': '그 남자는 털이 많아.'}, {'단어': 'scratch', '단어 뜻': '긁다', '품사': '동사', '예문': 'He’s scratching his head.', '예문 뜻': '그는 머리를 긁고 있어.'}, {'단어': 'stink', '단어 뜻': '냄새가 나다', '품사': '동사', '예문': 'The skunk stinks.', '예문 뜻': '그 스컹크는 냄새가 나.'}, {'단어': 'tread', '단어 뜻': '밟아 뭉개다', '품사': '동사', '예문': 'Don’t tread on the trees.', '예문 뜻': '나무를 밟아 뭉개지 마.'}]
# Parsed data for ./pdf_words/fly2.pdf page 16: [{'단어': 'drain', '단어 뜻': '물을 빼내다', '품사': '동사', '예문': 'They drained the water from the pool.', '예문 뜻': '그들은 수영장에서 물을 빼냈어.'}, {'단어': 'half', '단어 뜻': '반', '품사': '명사', '예문': 'I only have half of the harp.', '예문 뜻': '나는 하프의 반쪽만 가지고 있어.'}, {'단어': 'scoop', '단어 뜻': '(숟가락 같은 것으로) 푸다', '품사': '동사', '예문': 'Let’s scoop up the ice cream.', '예문 뜻': '아이스크림을 푸자.'}, {'단어': 'sprinkle', '단어 뜻': '뿌리다', '품사': '동사', '예문': 'I’m sprinkling some seeds on it.', '예문 뜻': '나는 그 위에 씨앗을 뿌리는 중이야.'}, {'단어': 'stuck', '단어 뜻': '(~에 빠져) 꼼짝 못하는', '품사': '형용사', '예문': 'The truck is stuck in the mud.', '예문 뜻': '트럭이 진흙에 빠져서 꼼짝 못해.'}, {'단어': 'stuff', '단어 뜻': '쑤셔 넣다', '품사': '동사', '예문': 'He stuffed some food into the bag.', '예문 뜻': '그는 음식을 가방에 쑤셔 넣었어.'}, {'단어': 'tear', '단어 뜻': '찢다', '품사': '동사', '예문': 'Don’t tear the letter.', '예문 뜻': '그 편지 찢지 마.'}, {'단어': 'vacant', '단어 뜻': '비어 있는', '품사': '형용사', '예문': 'The village is vacant.', '예문 뜻': '마을이 텅 비었어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 17: [{'단어': 'carry', '단어 뜻': '운반하다', '품사': '동사', '예문': 'I’m carrying some cans.', '예문 뜻': '나는 캔을 운반하고 있어.'}, {'단어': 'cheer', '단어 뜻': '응원하다', '품사': '동사', '예문': 'The cheerleader cheered the boy.', '예문 뜻': '치어리더가 그 소년을 응원했어.'}, {'단어': 'full', '단어 뜻': '가득한', '품사': '형용사', '예문': 'The pool is full of people.', '예문 뜻': '수영장이 사람들로 가득해.'}, {'단어': 'hang', '단어 뜻': '걸다', '품사': '동사', '예문': 'She is hanging the shirt.', '예문 뜻': '그녀가 셔츠를 걸고 있어.'}, {'단어': 'mark', '단어 뜻': '표시하다', '품사': '동사', '예문': 'I marked the item.', '예문 뜻': '나는 그 항목에 표시했어.'}, {'단어': 'raise', '단어 뜻': '들어 올리다', '품사': '동사', '예문': 'I can raise the letters.', '예문 뜻': '나는 글자들을 들어 올릴 수 있어.'}, {'단어': 'report', '단어 뜻': '보도하다, 알리다', '품사': '동사', '예문': 'He is reporting the news.', '예문 뜻': '그는 뉴스를 보도하는 중이야.'}, {'단어': 'wild', '단어 뜻': '격렬한, 거친', '품사': '형용사', '예문': 'The wind was wild.', '예문 뜻': '바람이 격렬했어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 18: [{'단어': 'announce', '단어 뜻': '발표하다, 선언하다', '품사': '동사', '예문': 'The announcer announced the news.', '예문 뜻': '아나운서가 그 소식을 발표했어.'}, {'단어': 'apart', '단어 뜻': '떨어져', '품사': '부사', '예문': 'The two buildings are far apart.', '예문 뜻': '두 건물이 멀리 떨어져 있어.'}, {'단어': 'chase', '단어 뜻': '뒤쫓다', '품사': '동사', '예문': 'The knight is chasing me.', '예문 뜻': '기사가 나를 뒤쫓고 있어.'}, {'단어': 'contain', '단어 뜻': '~이 들어 있다', '품사': '동사', '예문': 'It contains an elephant.', '예문 뜻': '거기에는 코끼리가 들어 있어.'}, {'단어': 'recycle', '단어 뜻': '재활용하다', '품사': '동사', '예문': 'We can recycle the cycle.', '예문 뜻': '우리는 그 자전거를 재활용할 수 있어.'}, {'단어': 'serve', '단어 뜻': '제공하다', '품사': '동사', '예문': 'The waiter served the starter.', '예문 뜻': '웨이터가 전채 요리를 제공했어.'}, {'단어': 'space', '단어 뜻': '공간', '품사': '명사', '예문': 'I need some space for a word.', '예문 뜻': '단어를 위한 공간이 좀 필요해.'}, {'단어': 'spin', '단어 뜻': '빙글빙글 돌다', '품사': '동사', '예문': 'The skater is spinning.', '예문 뜻': '스케이트 선수가 빙글빙글 돌고 있어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 19: [{'단어': 'court', '단어 뜻': '법정', '품사': '명사', '예문': 'A judge is in court.', '예문 뜻': '판사가 법정에 있어.'}, {'단어': 'exchange', '단어 뜻': '교환하다', '품사': '동사', '예문': 'Let’s exchange bags.', '예문 뜻': '가방을 교환하자.'}, {'단어': 'gather', '단어 뜻': '모이다', '품사': '동사', '예문': 'Let’s gather in the room.', '예문 뜻': '방에서 모이자.'}, {'단어': 'knit', '단어 뜻': '(실로 옷 등을) 뜨다', '품사': '동사', '예문': 'She is knitting the sweater.', '예문 뜻': '그녀는 스웨터를 뜨고 있어.'}, {'단어': 'navigate', '단어 뜻': '길을 찾다, 항해하다', '품사': '동사', '예문': 'We navigate with a navigation system.', '예문 뜻': '우리는 네비게이션을 이용해 길을 찾아.'}, {'단어': 'scan', '단어 뜻': '훑어보다', '품사': '동사', '예문': 'I scanned the boy.', '예문 뜻': '나는 그 소년을 훑어봤어.'}, {'단어': 'sew', '단어 뜻': '바느질하다', '품사': '동사', '예문': 'She is sewing the socks.', '예문 뜻': '그녀는 양말을 바느질하고 있어.'}, {'단어': 'straight', '단어 뜻': '곧은', '품사': '형용사', '예문': 'Her hair is straight.', '예문 뜻': '그녀의 머리카락은 곧아.'}]
# Parsed data for ./pdf_words/fly2.pdf page 20: [{'단어': 'familiar', '단어 뜻': '친숙한', '품사': '형용사', '예문': 'The family is familiar to me.', '예문 뜻': '그 가족은 나에게 친숙해.'}, {'단어': 'guard', '단어 뜻': '지키다', '품사': '동사', '예문': 'They are guarding the start.', '예문 뜻': '그들은 그 스타를 지키고 있어.'}, {'단어': 'harmful', '단어 뜻': '해로운', '품사': '형용사', '예문': 'Ham is harmful to our health.', '예문 뜻': '햄은 우리 건강에 해로워.'}, {'단어': 'pause', '단어 뜻': '잠시 멈추다', '품사': '동사', '예문': 'Pause in front of the camera.', '예문 뜻': '카메라 앞에서 잠시 멈춰.'}, {'단어': 'stain', '단어 뜻': '얼룩', '품사': '명사', '예문': 'There are stains on the bowl.', '예문 뜻': '그릇에 얼룩이 있어.'}, {'단어': 'stretch', '단어 뜻': '늘이다', '품사': '동사', '예문': 'Stretch your body', '예문 뜻': '몸을 쭉 늘여.'}, {'단어': 'sweep', '단어 뜻': '쓸다', '품사': '동사', '예문': 'Please sweep up the sweets.', '예문 뜻': '제발 단것들을 쓸어버려.'}, {'단어': 'switch', '단어 뜻': '바꾸다', '품사': '동사', '예문': 'Let’s switch the switches.', '예문 뜻': '스위치를 바꾸자.'}]
# Parsed data for ./pdf_words/fly2.pdf page 21: [{'단어': 'belly', '단어 뜻': '배', '품사': '명사', '예문': 'Shake your belly.', '예문 뜻': '네 배를 흔들어.'}, {'단어': 'bony', '단어 뜻': '앙상한', '품사': '형용사', '예문': 'The bony man looks sad.', '예문 뜻': '그 앙상한 남자는 슬퍼 보여.'}, {'단어': 'cheat', '단어 뜻': '속이다', '품사': '동사', '예문': 'She cheated me on the price.', '예문 뜻': '그녀가 나에게 가격을 속였어.'}, {'단어': 'clap', '단어 뜻': '손뼉을 치다', '품사': '동사', '예문': 'The crab is clapping.', '예문 뜻': '게가 손뼉을 치고 있어.'}, {'단어': 'guess', '단어 뜻': '추측하다', '품사': '동사', '예문': 'Guess who the guest is.', '예문 뜻': '손님이 누구인지 추측해 봐.'}, {'단어': 'pack', '단어 뜻': '싸다, 챙기다', '품사': '동사', '예문': 'I packed the stuff into the backpack.', '예문 뜻': '나는 배낭에 물건을 챙겨 넣었어.'}, {'단어': 'pal', '단어 뜻': '친구', '품사': '명사', '예문': 'I have a pal in France.', '예문 뜻': '나는 프랑스에 친구가 있어.'}, {'단어': 'set', '단어 뜻': '준비가 된', '품사': '형용사', '예문': 'I’m all set for lunch.', '예문 뜻': '나는 점심 먹을 준비가 됐어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 22: [{'단어': 'amazing', '단어 뜻': '놀라운', '품사': '형용사', '예문': 'The Amazon is amazing.', '예문 뜻': '아마존은 놀라워.'}, {'단어': 'bitter', '단어 뜻': '맛이 쓴', '품사': '형용사', '예문': 'This butter tastes bitter.', '예문 뜻': '이 버터는 맛이 써.'}, {'단어': 'face', '단어 뜻': '~을 마주 보다', '품사': '동사', '예문': 'I’m facing her face.', '예문 뜻': '나는 그녀의 얼굴을 마주 보고 있어.'}, {'단어': 'flake', '단어 뜻': '조각', '품사': '명사', '예문': 'Flakes of corn started to fall from the sky.', '예문 뜻': '하늘에서 옥수수 조각들이 떨어지기 시작했어.'}, {'단어': 'long', '단어 뜻': '간절히 바라다', '품사': '동사', '예문': 'I long to be tall.', '예문 뜻': '나는 키가 커지길 간절히 바라.'}, {'단어': 'mad', '단어 뜻': '몹시 화가 난', '품사': '형용사', '예문': 'She is mad about the mat.', '예문 뜻': '그녀는 매트 때문에 몹시 화가 났어.'}, {'단어': 'stare', '단어 뜻': '빤히 쳐다보다', '품사': '동사', '예문': 'I stared at the star.', '예문 뜻': '나는 그 스타를 빤히 쳐다봤어.'}, {'단어': 'survive', '단어 뜻': '살아남다', '품사': '동사', '예문': 'She survived in the survival game.', '예문 뜻': '그녀는 서바이벌 게임에서 살아남았어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 23: [{'단어': 'beg', '단어 뜻': '애원하다', '품사': '동사', '예문': 'The boy begged for the bag.', '예문 뜻': '소년이 가방을 애원했어.'}, {'단어': 'bump', '단어 뜻': '부딪치다', '품사': '동사', '예문': 'I bumped into a bumper car.', '예문 뜻': '나는 범퍼카에 부딪혔어.'}, {'단어': 'hand', '단어 뜻': '건네주다', '품사': '동사', '예문': 'She handed me something.', '예문 뜻': '그녀가 나에게 뭔가를 건넸어.'}, {'단어': 'horror', '단어 뜻': '공포', '품사': '명사', '예문': 'I began to shake in horror.', '예문 뜻': '나는 무서워서 떨기 시작했어.'}, {'단어': 'rock', '단어 뜻': '흔들리다', '품사': '동사', '예문': 'The rock is rocking.', '예문 뜻': '그 바위가 흔들리고 있어.'}, {'단어': 'sneak', '단어 뜻': '살금살금 가다', '품사': '동사', '예문': 'I sneaked into the dark room.', '예문 뜻': '나는 어두운 방으로 살금살금 들어갔어.'}, {'단어': 'thrilling', '단어 뜻': '아주 신나는', '품사': '형용사', '예문': 'The rollercoaster is thrilling.', '예문 뜻': '그 롤러코스터는 아주 신나.'}, {'단어': 'tight', '단어 뜻': '꽉 끼는', '품사': '형용사', '예문': 'The tights are too tight.', '예문 뜻': '타이츠가 너무 꽉 끼어.'}]
# Parsed data for ./pdf_words/fly2.pdf page 24: [{'단어': 'chicken', '단어 뜻': '겁쟁이인', '품사': '형용사', '예문': 'The chicken is so chicken.', '예문 뜻': '그 닭은 매우 겁쟁이야.'}, {'단어': 'crack', '단어 뜻': '(갈라져 생긴) 금', '품사': '명사', '예문': 'There is a crack in the cracker.', '예문 뜻': '그 크래커에 금이 갔어.'}, {'단어': 'fish', '단어 뜻': '수상한', '품사': '형용사', '예문': 'There is something fishy about the fish.', '예문 뜻': '그 물고기는 뭔가 수상해.'}, {'단어': 'lounge', '단어 뜻': '느긋하게 앉아 있다', '품사': '동사', '예문': 'I always lounge at the lounge.', '예문 뜻': '나는 항상 라운지에 느긋하게 안자 있어.'}, {'단어': 'nosy', '단어 뜻': '참견하기 좋아하는', '품사': '형용사', '예문': 'The man is too nosy.', '예문 뜻': '그 남자는 참 참견하기 좋아해.'}, {'단어': 'race', '단어 뜻': '쏜살같이 가다', '품사': '동사', '예문': 'The cars raced down the hill.', '예문 뜻': '자동차들이 쏜살같이 달려 내려갔어.'}, {'단어': 'trip', '단어 뜻': '걸려 넘어지다', '품사': '동사', '예문': 'I tripped over the bag.', '예문 뜻': '나는 가방에 걸려 넘어졌어.'}, {'단어': 'wrinkle', '단어 뜻': '찡그리다', '품사': '동사', '예문': 'The girl wrinkled her eyebrows.', '예문 뜻': '그 소녀는 눈썹을 찡그렸어.'}]
# beyond.pdf를 처리하는 중...
# Parsed data for ./pdf_words/jump2.pdf page 1: [{'단어': 'brush', '단어 뜻': '빗다', '품사': '동사', '예문': 'You must brush your hair every day.', '예문 뜻': '너는 매일 머리를 빗어야 해.'}, {'단어': 'hello', '단어 뜻': '여보세\n요', '품사': '감탄사', '예문': 'Hello?', '예문 뜻': '여보세요?'}, {'단어': 'helmet', '단어 뜻': '헬멧', '품사': '명사', '예문': 'You must wear your helmet.', '예문 뜻': '너는 헬멧을 써야 해.'}, {'단어': 'hold on', '단어 뜻': '기다리다', '품사': '', '예문': 'Hold on, please.', '예문 뜻': '잠시만 기다려 주세요.'}, {'단어': 'line', '단어 뜻': '줄', '품사': '명사', '예문': 'You must stand in line at a bus stop.', '예문 뜻': '너는 버스 정류장에서 줄을 서야 해.'}, {'단어': 'number', '단어 뜻': '번호', '품사': '명사', '예문': 'You have the wrong number.', '예문 뜻': '전화를 잘못 거셨습니다.'}, {'단어': 'phone', '단어 뜻': '전화', '품사': '명사', '예문': 'Can you get the phone for me?', '예문 뜻': '전화 좀 대신 받아 주실래요?'}, {'단어': 'quiet', '단어 뜻': '조용한', '품사': '형용사', '예문': 'You must be quiet in the library.', '예문 뜻': '너는 도서관에서는 조용히 해야 해.'}, {'단어': 'speak', '단어 뜻': '통화하다', '품사': '동사', '예문': 'May I speak to Yuna?', '예문 뜻': '유나와 통화할 수 있을까요?'}, {'단어': 'watch out', '단어 뜻': '조심하다', '품사': '', '예문': 'You must watch out for cars.', '예문 뜻': '너는 자동차를 조심해야 해.'}]
# Parsed data for ./pdf_words/jump2.pdf page 2: [{'단어': 'garden', '단어 뜻': '정원', '품사': '명사', '예문': 'There is a garden in my house.', '예문 뜻': '우리 집에는 정원이 있어.'}, {'단어': 'inside', '단어 뜻': '안에, 안으\n로', '품사': '부사', '예문': 'Tim and his dog are inside the room.', '예문 뜻': 'Tim과 그의 개는 방 안에 있어.'}, {'단어': 'sink', '단어 뜻': '싱크대', '품사': '명사', '예문': 'There are many dishes in the sink.', '예문 뜻': '싱크대 안에 접시가 많이 있어.'}, {'단어': 'soap', '단어 뜻': '비누', '품사': '명사', '예문': 'There is soap in the bathroom.', '예문 뜻': '욕실에는 비누가 있어.'}, {'단어': 'stove', '단어 뜻': '가스레인\n지', '품사': '명사', '예문': 'There is a stove in the kitchen.', '예문 뜻': '부엌에는 가스레인지가 있어.'}, {'단어': 'surprise', '단어 뜻': '놀람', '품사': '명사', '예문': 'What a surprise!', '예문 뜻': '놀랍다!'}, {'단어': 'toilet', '단어 뜻': '변기', '품사': '명사', '예문': 'There is a toilet in the bathroom.', '예문 뜻': '욕실에는 변기가 있어.'}, {'단어': 'toothbrush', '단어 뜻': '칫솔', '품사': '명사', '예문': 'There is a toothbrush in the bathroom.', '예문 뜻': '욕실에는 칫솔이 있어.'}, {'단어': 'toothpaste', '단어 뜻': '치약', '품사': '명사', '예문': 'There is toothpaste in the bathroom.', '예문 뜻': '욕실에는 치약이 있어.'}, {'단어': 'welcome', '단어 뜻': '환영하다', '품사': '동사', '예문': 'Welcome to my house.', '예문 뜻': '우리 집에 온 것을 환영해.'}]
# Parsed data for ./pdf_words/jump2.pdf page 3: [{'단어': 'answer', '단어 뜻': '대답하다', '품사': '동사', '예문': 'You have to answer my questions.', '예문 뜻': '너는 내 질문들에 대답해야 해.'}, {'단어': 'ask', '단어 뜻': '묻다', '품사': '동사', '예문': 'May I ask you a question?', '예문 뜻': '질문 하나 해도 될까?'}, {'단어': 'fire', '단어 뜻': '불', '품사': '명사', '예문': 'We must watch out for fire.', '예문 뜻': '우리는 불을 조심해야 해.'}, {'단어': 'know', '단어 뜻': '알다', '품사': '동사', '예문': 'I know the answer.', '예문 뜻': '나는 그 답을 알아.'}, {'단어': 'leave', '단어 뜻': '남가다', '품사': '동사', '예문': 'I must leave a flower for him.', '예문 뜻': '나는 그를 위해 꽃 한 송이를 남겨야 해.'}, {'단어': 'must', '단어 뜻': '~해야 하\n다', '품사': '동사', '예문': 'You must wake up!', '예문 뜻': '너는 일어나야 해!'}, {'단어': 'question', '단어 뜻': '질문', '품사': '명사', '예문': 'I have some questions.', '예문 뜻': '몇 가지 질문이 있어요.'}, {'단어': 'study', '단어 뜻': '공부하다', '품사': '동사', '예문': 'I must study English.', '예문 뜻': '나는 영어 공부를 해야 해.'}, {'단어': 'take care', '단어 뜻': '안녕, 잘 가', '품사': '', '예문': 'Take care.', '예문 뜻': '안녕, 잘 가.'}, {'단어': 'word', '단어 뜻': '단어', '품사': '명사', '예문': 'I can spell many English words.', '예문 뜻': '나는 많은 영어 단어의 철자를 말할 수 있어.'}]
# Parsed data for ./pdf_words/jump2.pdf page 4: [{'단어': 'building', '단어 뜻': '건물', '품사': '명사', '예문': 'There are many building in the city.', '예문 뜻': '도시에는 많은 건물들이 있어.'}, {'단어': 'cousin', '단어 뜻': '사촌', '품사': '명사', '예문': 'They are my cousins.', '예문 뜻': '그들은 내 사촌들이야.'}, {'단어': 'duck', '단어 뜻': '오리', '품사': '명사', '예문': 'This is a baby duck.', '예문 뜻': '이것은 새끼 오리야.'}, {'단어': 'goat', '단어 뜻': '염소', '품사': '명사', '예문': 'This goat is black.', '예문 뜻': '이 염소는 검은색이야.'}, {'단어': 'handsome', '단어 뜻': '잘생긴', '품사': '형용사', '예문': 'Tony is handsome.', '예문 뜻': 'Tony는 잘생겼어.'}, {'단어': 'horse', '단어 뜻': '말', '품사': '명사', '예문': 'This horse is brown.', '예문 뜻': '이 말은 갈색이야.'}, {'단어': 'lovely', '단어 뜻': '사랑스\n러운', '품사': '형용사', '예문': 'Jenny is so lovely.', '예문 뜻': 'Jenny는 무척 사랑스러워.'}, {'단어': 'sheep', '단어 뜻': '양', '품사': '명사', '예문': 'The sheep looks cute.', '예문 뜻': '그 양은 귀여워 보여.'}, {'단어': 'smile', '단어 뜻': '미소', '품사': '명사', '예문': 'Justin has a lovely smile.', '예문 뜻': 'Justin은 사랑스러운 미소를 가지고 있어.'}, {'단어': 'year', '단어 뜻': '~살', '품사': '명사', '예문': 'Jenny is six years old.', '예문 뜻': 'Jenny는 여섯 살이야.'}]
# ...
# Parsed data for ./pdf_words/start.pdf page 5: [{'단어': 'brother', '단어 뜻': '남자 형제', '품사': '', '예문': 'He is my brother.', '예문 뜻': '그는 내 오빠(형/남동생)야.'}, {'단어': 'dad', '단어 뜻': '아빠', '품사': '', '예문': 'He is my dad.', '예문 뜻': '그는 우리 아빠야.'}, {'단어': 'he', '단어 뜻': '그', '품사': '', '예문': 'He is Mark.', '예문 뜻': '그는 Mark야.'}, {'단어': 'I', '단어 뜻': '나', '품사': '', '예문': 'I am Harry.', '예문 뜻': '나는 Harry야.'}, {'단어': 'mom', '단어 뜻': '엄마', '품사': '', '예문': 'She is my mom.', '예문 뜻': '그녀는 우리 엄마야.'}, {'단어': 'she', '단어 뜻': '그녀', '품사': '', '예문': 'She is Julia.', '예문 뜻': '그녀는 Julia야.'}, {'단어': 'sister', '단어 뜻': '여자 형제', '품사': '', '예문': 'She is my sister.', '예문 뜻': '그녀는 내 여동생(누나/언니)이야.'}, {'단어': 'they', '단어 뜻': '그들', '품사': '', '예문': 'They are friends.', '예문 뜻': '그들은 친구들이야.'}, {'단어': 'we', '단어 뜻': '우리', '품사': '', '예문': 'We are friends.', '예문 뜻': '우리는 친구들이야.'}, {'단어': 'you', '단어 뜻': '너', '품사': '', '예문': 'You are Betty.', '예문 뜻': '너는 Betty야.'}, {'단어': 'beach', '단어 뜻': '해변', '품사': '', '예문': 'Looks at the beach.', '예문 뜻': '해변을 봐.'}, {'단어': 'flower', '단어 뜻': '꽃', '품사': '', '예문': 'Look! It’s a flower.', '예문 뜻': '봐! 그것은 꽃이야.'}, {'단어': 'lake', '단어 뜻': '호수', '품사': '', '예문': 'Look! It’s a lake.', '예문 뜻': '봐! 그것은 호수야.'}, {'단어': 'moon', '단어 뜻': '달', '품사': '', '예문': 'Look at the moon.', '예문 뜻': '달을 봐.'}, {'단어': 'mountain', '단어 뜻': '산', '품사': '', '예문': 'Look! It’s a mountain.', '예문 뜻': '봐! 그것은 산이야.'}, {'단어': 'river', '단어 뜻': '강', '품사': '', '예문': 'Look at the river.', '예문 뜻': '강을 봐.'}, {'단어': 'sea', '단어 뜻': '바다', '품사': '', '예문': 'Look at the sea.', '예문 뜻': '바다를 봐.'}, {'단어': 'sky', '단어 뜻': '하늘', '품사': '', '예문': 'Look at the sky', '예문 뜻': '하늘을 봐.'}, {'단어': 'sun', '단어 뜻': '태양', '품사': '', '예문': 'Look at the sun.', '예문 뜻': '태양을 봐.'}, {'단어': 'tree', '단어 뜻': '나무', '품사': '', '예문': 'Look at the tree', '예문 뜻': '나무를 봐.'}]
# Parsed data for ./pdf_words/start.pdf page 6: [{'단어': 'bed', '단어 뜻': '침대', '품사': '', '예문': 'The bed is brown.', '예문 뜻': '그 침대는 갈색이야.'}, {'단어': 'chair', '단어 뜻': '의자', '품사': '', '예문': 'The chair is blue.', '예문 뜻': '그 의자는 파란색이야.'}, {'단어': 'computer', '단어 뜻': '컴퓨터', '품사': '', '예문': 'The computer is gray.', '예문 뜻': '그 컴퓨터는 회색이야.'}, {'단어': 'desk', '단어 뜻': '책상', '품사': '', '예문': 'The desk is white.', '예문 뜻': '그 책상은 흰색이야'}, {'단어': 'lamp', '단어 뜻': '전등', '품사': '', '예문': 'The lamp is pink.', '예문 뜻': '그 전등은 분홍색이야.'}, {'단어': 'radio', '단어 뜻': '라디오', '품사': '', '예문': 'The radio is yellow.', '예문 뜻': '그 라디오는 노란색이야.'}, {'단어': 'sofa', '단어 뜻': '소파', '품사': '', '예문': 'The sofa is black.', '예문 뜻': '그 소파는 검정색이야.'}, {'단어': 'table', '단어 뜻': '탁자', '품사': '', '예문': 'The table is green.', '예문 뜻': '그 탁자는 녹색이야.'}, {'단어': 'telephone', '단어 뜻': '전화', '품사': '', '예문': 'The telephone is white.', '예문 뜻': '그 전화기는 흰색이야.'}, {'단어': 'television', '단어 뜻': '텔레비전', '품사': '', '예문': 'The television is red.', '예문 뜻': '그 텔레비전은 빨간색이야.'}, {'단어': 'my', '단어 뜻': '나의', '품사': '', '예문': 'This is my doll.', '예문 뜻': '이것은 내 인형이야.'}, {'단어': 'your', '단어 뜻': '너의', '품사': '', '예문': 'That is your robot.', '예문 뜻': '저것은 네 로봇이야.'}, {'단어': 'his', '단어 뜻': '그의', '품사': '', '예문': 'This is his pen.', '예문 뜻': '이것은 그의 펜이야.'}, {'단어': 'her', '단어 뜻': '그녀의', '품사': '', '예문': 'That is her book.', '예문 뜻': '저것은 그녀의 책이야.'}, {'단어': 'their', '단어 뜻': '그들의', '품사': '', '예문': 'These are their pencils.', '예문 뜻': '이것들은 그들의 연필이야.'}, {'단어': 'our', '단어 뜻': '우리의', '품사': '', '예문': 'Those are our cookies.', '예문 뜻': '저것들은 우리의 쿠키야.'}, {'단어': 'pen', '단어 뜻': '펜', '품사': '', '예문': 'It’s my pen.', '예문 뜻': '그것은 내 펜이야.'}, {'단어': 'pencil', '단어 뜻': '연필', '품사': '', '예문': 'It’s your pencil.', '예문 뜻': '그것은 네 연필이야.'}, {'단어': 'eraser', '단어 뜻': '지우개', '품사': '', '예문': 'It’s her eraser.', '예문 뜻': '그것은 그녀의 지우개야.'}, {'단어': 'crayon', '단어 뜻': '크레용', '품사': '', '예문': 'It’s his crayon.', '예문 뜻': '그것은 그의 크레용이야.'}]
# Parsed data for ./pdf_words/start.pdf page 7: [{'단어': 'frog', '단어 뜻': '개구리', '품사': '', '예문': 'I like frogs.', '예문 뜻': '나는 개구리를 좋아해.'}, {'단어': 'giraffe', '단어 뜻': '기린', '품사': '', '예문': 'I like giraffes.', '예문 뜻': '나는 기린을 좋아해.'}, {'단어': 'kangaroo', '단어 뜻': '캥거루', '품사': '', '예문': 'I like kangaroos.', '예문 뜻': '나는 캥거루를 좋아해.'}, {'단어': 'lion', '단어 뜻': '사자', '품사': '', '예문': 'I like lions.', '예문 뜻': '나는 사자를 좋아해.'}, {'단어': 'mouse', '단어 뜻': '쥐', '품사': '', '예문': 'It’s a mouse.', '예문 뜻': '그것은 쥐야.'}, {'단어': 'rabbit', '단어 뜻': '토끼', '품사': '', '예문': 'I don’t like rabbits.', '예문 뜻': '나는 토기를 좋아하지 않아.'}, {'단어': 'spider', '단어 뜻': '거미', '품사': '', '예문': 'I don’t like spiders.', '예문 뜻': '나는 거미를 좋아하지 않아.'}, {'단어': 'turtle', '단어 뜻': '거북이', '품사': '', '예문': 'I don’t like turtles.', '예문 뜻': '나는 거북이를 좋아하지 않아.'}, {'단어': 'wolf', '단어 뜻': '늑대', '품사': '', '예문': 'It’s a wolf.', '예문 뜻': '그것은 늑대야.'}, {'단어': 'zebra', '단어 뜻': '얼룩말', '품사': '', '예문': 'It’s a zebra.', '예문 뜻': '그것은 얼룩말이야.'}, {'단어': 'clothes', '단어 뜻': '옷', '품사': '', '예문': 'They are my clothes.', '예문 뜻': '그것들은 나의 옷이야.'}, {'단어': 'coat', '단어 뜻': '코트', '품사': '', '예문': 'It’s your coat.', '예문 뜻': '그것은 네 코트야.'}, {'단어': 'jacket', '단어 뜻': '재킷', '품사': '', '예문': 'It’s my jacket.', '예문 뜻': '그것은 내 재킷이야.'}, {'단어': 'jeans', '단어 뜻': '청바지', '품사': '', '예문': 'These are his jeans.', '예문 뜻': '이것들은 그의 청바지야.'}, {'단어': 'pants', '단어 뜻': '바지', '품사': '', '예문': 'They are her pants.', '예문 뜻': '그것들은 그녀의 바지야.'}, {'단어': 'shirt', '단어 뜻': '셔츠', '품사': '', '예문': 'It’s your shirt.', '예문 뜻': '그것은 네 셔츠야.'}, {'단어': 'shoes', '단어 뜻': '신발', '품사': '', '예문': 'These are your shoes.', '예문 뜻': '이것들은 네 신발이야.'}, {'단어': 'skirt', '단어 뜻': '치마', '품사': '', '예문': 'This is my skirt.', '예문 뜻': '이것은 내 치마야.'}, {'단어': 'socks', '단어 뜻': '양말', '품사': '', '예문': 'These are my socks.', '예문 뜻': '이것들은 내 양말이야.'}, {'단어': 'sweater', '단어 뜻': '스웨터', '품사': '', '예문': 'It’s my sweater.', '예문 뜻': '그것은 내 스웨터야.'}]
# Parsed data for ./pdf_words/start.pdf page 8: [{'단어': 'angry', '단어 뜻': '화난', '품사': '', '예문': 'I’m angry.', '예문 뜻': '나는 화나.'}, {'단어': 'happy', '단어 뜻': '행복한', '품사': '', '예문': 'I’m happy.', '예문 뜻': '나는 행복해.'}, {'단어': 'hungry', '단어 뜻': '배고픈', '품사': '', '예문': 'He is hungry.', '예문 뜻': '그는 배고파.'}, {'단어': 'sad', '단어 뜻': '슬픈', '품사': '', '예문': 'She is sad.', '예문 뜻': '그녀는 슬퍼.'}, {'단어': 'scared', '단어 뜻': '무서운', '품사': '', '예문': 'She is scared.', '예문 뜻': '그녀가 무섭대.'}, {'단어': 'sick', '단어 뜻': '아픈', '품사': '', '예문': 'You are sick.', '예문 뜻': '너는 아프구나.'}, {'단어': 'sorry', '단어 뜻': '미안한', '품사': '', '예문': 'I’m sorry.', '예문 뜻': '미안해.'}, {'단어': 'surprised', '단어 뜻': '놀란', '품사': '', '예문': 'He is surprised.', '예문 뜻': '그가 놀랐어.'}, {'단어': 'thirsty', '단어 뜻': '목마른', '품사': '', '예문': 'I’m thirsty.', '예문 뜻': '나는 목말라.'}, {'단어': 'tired', '단어 뜻': '피곤한', '품사': '', '예문': 'I’m tired.', '예문 뜻': '나는 피곤해.'}, {'단어': 'bag', '단어 뜻': '가방', '품사': '', '예문': 'It’s my bag.', '예문 뜻': '그것은 내 가방이야.'}, {'단어': 'belt', '단어 뜻': '허리띠', '품사': '', '예문': 'Your belt is short.', '예문 뜻': '네 허리띠는 짧구나.'}, {'단어': 'boots', '단어 뜻': '부츠', '품사': '', '예문': 'Her boots are black.', '예문 뜻': '그녀의 부츠는 검은색이야.'}, {'단어': 'cap', '단어 뜻': '야구 모자', '품사': '', '예문': 'It’s my cap.', '예문 뜻': '그것은 내 야구 모자야.'}, {'단어': 'gloves', '단어 뜻': '장갑', '품사': '', '예문': 'Your gloves are big.', '예문 뜻': '네 장갑은 크구나.'}, {'단어': 'hat', '단어 뜻': '모자', '품사': '', '예문': 'It’s my hat.', '예문 뜻': '그것은 내 모자야.'}, {'단어': 'pajamas', '단어 뜻': '파자마', '품사': '', '예문': 'His pajamas are small.', '예문 뜻': '그의 파자마는 작아.'}, {'단어': 'scarf', '단어 뜻': '스카프', '품사': '', '예문': 'Your scarf is long.', '예문 뜻': '네 스카프는 길구나.'}, {'단어': 'shorts', '단어 뜻': '반바지', '품사': '', '예문': 'My shorts are green.', '예문 뜻': '내 반바지는 초록색이야.'}, {'단어': 'vest', '단어 뜻': '조끼', '품사': '', '예문': 'It’s my vest.', '예문 뜻': '그것은 내 조끼야.'}]
# Parsed data for ./pdf_words/start.pdf page 9: [{'단어': 'cake', '단어 뜻': '케이크', '품사': '', '예문': 'You like cake.', '예문 뜻': '너는 케이크를 좋아하는구나.'}, {'단어': 'chicken', '단어 뜻': '통닭', '품사': '', '예문': 'I want chicken.', '예문 뜻': '나는 통닭을 원해.'}, {'단어': 'curry', '단어 뜻': '카레', '품사': '', '예문': 'You like curry.', '예문 뜻': '너는 카레를 좋아하는구나.'}, {'단어': 'French fries', '단어 뜻': '감자 튀김', '품사': '', '예문': 'They like French fries.', '예문 뜻': '그들은 감자 튀김을 좋아해.'}, {'단어': 'hot dog', '단어 뜻': '핫도그', '품사': '', '예문': 'I want a hot dog.', '예문 뜻': '나는 핫도그를 원해.'}, {'단어': 'milk', '단어 뜻': '우유', '품사': '', '예문': 'I want milk.', '예문 뜻': '나는 우유를 원해.'}, {'단어': 'spaghetti', '단어 뜻': '스파게티', '품사': '', '예문': 'I want spaghetti.', '예문 뜻': '나는 스파게티를 원해.'}, {'단어': 'steak', '단어 뜻': '스테이크', '품사': '', '예문': 'We like steak.', '예문 뜻': '우리는 스테이크를 좋아해.'}, {'단어': 'tea', '단어 뜻': '티', '품사': '', '예문': 'We want tea.', '예문 뜻': '우리는 차를 원해.'}, {'단어': 'water', '단어 뜻': '물', '품사': '', '예문': 'They want water.', '예문 뜻': '그들은 물을 원해.'}, {'단어': 'close', '단어 뜻': '닫다', '품사': '', '예문': 'Close the door.', '예문 뜻': '문을 닫아.'}, {'단어': 'come', '단어 뜻': '오다', '품사': '', '예문': 'Come here, please.', '예문 뜻': '여기로 오세요.'}, {'단어': 'do', '단어 뜻': '하다', '품사': '', '예문': 'I can do it.', '예문 뜻': '나는 할 수 있어.'}, {'단어': 'fly', '단어 뜻': '날다', '품사': '', '예문': 'I can fly.', '예문 뜻': '나는 날 수 있어.'}, {'단어': 'go', '단어 뜻': '가다', '품사': '', '예문': 'Go there, please.', '예문 뜻': '거기로 가 주세요.'}, {'단어': 'make', '단어 뜻': '만들다', '품사': '', '예문': 'I can make cookies.', '예문 뜻': '나는 쿠키를 만들 수 있어.'}, {'단어': 'open', '단어 뜻': '열다', '품사': '', '예문': 'Open the window.', '예문 뜻': '창문을 열어.'}, {'단어': 'sit', '단어 뜻': '앉다', '품사': '', '예문': 'Sit down.', '예문 뜻': '앉아.'}, {'단어': 'stand', '단어 뜻': '서다', '품사': '', '예문': 'Stand up.', '예문 뜻': '일어서'}, {'단어': 'stop', '단어 뜻': '멈추다', '품사': '', '예문': 'Stop here, please.', '예문 뜻': '여기에 멈추세요.'}]
# Parsed data for ./pdf_words/start.pdf page 10: [{'단어': 'big', '단어 뜻': '큰', '품사': '', '예문': 'It’s big.', '예문 뜻': '그것은 커.'}, {'단어': 'small', '단어 뜻': '작은', '품사': '', '예문': 'It’s small.', '예문 뜻': '그것은 작아.'}, {'단어': 'long', '단어 뜻': '긴', '품사': '', '예문': 'It’s long.', '예문 뜻': '그것은 길어.'}, {'단어': 'short', '단어 뜻': '짧은', '품사': '', '예문': 'It’s short.', '예문 뜻': '그것은 짧아.'}, {'단어': 'heavy', '단어 뜻': '무거운', '품사': '', '예문': 'It’s heavy.', '예문 뜻': '그것은 무거워.'}, {'단어': 'light', '단어 뜻': '가벼운', '품사': '', '예문': 'It’s light.', '예문 뜻': '그것은 가벼워.'}, {'단어': 'hard', '단어 뜻': '딱딱한', '품사': '', '예문': 'It’s a hard ball.', '예문 뜻': '그것은 딱딱한 공이야.'}, {'단어': 'soft', '단어 뜻': '부드러운', '품사': '', '예문': 'It’s a soft sweater.', '예문 뜻': '그것은 부드러운 스웨터야.'}, {'단어': 'old', '단어 뜻': '낡은', '품사': '', '예문': 'It’s an old car.', '예문 뜻': '그것은 낡은 자동차야.'}, {'단어': 'new', '단어 뜻': '새로운', '품사': '', '예문': 'It’s a new computer.', '예문 뜻': '그것은 새로운 컴퓨터야.'}, {'단어': 'fork', '단어 뜻': '포크', '품사': '', '예문': 'It’s a fork.', '예문 뜻': '그것은 포크야.'}, {'단어': 'knife', '단어 뜻': '칼', '품사': '', '예문': 'It’s a knife.', '예문 뜻': '그것은 칼이야.'}, {'단어': 'spoon', '단어 뜻': '숟가락', '품사': '', '예문': 'It’s a spoon.', '예문 뜻': '그것은 숟가락이야.'}, {'단어': 'cup', '단어 뜻': '컵', '품사': '', '예문': 'It’s a cup.', '예문 뜻': '그것은 컵이야.'}, {'단어': 'dish', '단어 뜻': '접시', '품사': '', '예문': 'It’s a dish.', '예문 뜻': '그것은 접시야.'}, {'단어': 'lunch box', '단어 뜻': '도시락', '품사': '', '예문': 'It’s a lunch box.', '예문 뜻': '그것은 도시락이야.'}, {'단어': 'breakfast', '단어 뜻': '아침 식사', '품사': '', '예문': 'I have breakfast.', '예문 뜻': '나는 아침을 먹어.'}, {'단어': 'lunch', '단어 뜻': '점심 식사', '품사': '', '예문': 'I have lunch.', '예문 뜻': '나는 점심을 먹어.'}, {'단어': 'dinner', '단어 뜻': '저녁 식사', '품사': '', '예문': 'I have dinner.', '예문 뜻': '나는 저녁을 먹어.'}, {'단어': 'snack', '단어 뜻': '간식', '품사': '', '예문': 'I have snacks.', '예문 뜻': '나는 간식을 먹어.'}]
# Parsed data for ./pdf_words/start.pdf page 11: [{'단어': 'dance', '단어 뜻': '춤추다', '품사': '', '예문': 'Look! She can dance.', '예문 뜻': '봐! 그녀는 춤출 수 있어.'}, {'단어': 'jump', '단어 뜻': '깡충 뛰다', '품사': '', '예문': 'I can jump.', '예문 뜻': '나는 깡충 뛸 수 있어.'}, {'단어': 'pull', '단어 뜻': '끌다', '품사': '', '예문': 'He can pull the car.', '예문 뜻': '그는 그 자동차를 끌 수 있어.'}, {'단어': 'push', '단어 뜻': '밀다', '품사': '', '예문': 'Look! He can push the car.', '예문 뜻': '봐! 그는 자동차를 밀 수 있 어.'}, {'단어': 'run', '단어 뜻': '달리다', '품사': '', '예문': 'Look! I can run.', '예문 뜻': '봐! 나는 달릴 수 있어.'}, {'단어': 'sing', '단어 뜻': '노래하다', '품사': '', '예문': 'She can sing.', '예문 뜻': '그녀는 노래할 수 있어.'}, {'단어': 'skate', '단어 뜻': '스케이트를 타\n다', '품사': '', '예문': 'He can’t skate.', '예문 뜻': '그는 스케이트를 탈 수 없어.'}, {'단어': 'ski', '단어 뜻': '스키를 타다', '품사': '', '예문': 'She can’t ski.', '예문 뜻': '그녀는 스키를 탈 수 없어.'}, {'단어': 'swim', '단어 뜻': '수영하다', '품사': '', '예문': 'I can’t swim.', '예문 뜻': '나는 수영할 수 없어.'}, {'단어': 'walk', '단어 뜻': '걷다', '품사': '', '예문': 'I can walk.', '예문 뜻': '나는 걸을 수 있어.'}, {'단어': 'birthday', '단어 뜻': '생일', '품사': '', '예문': 'Happy birthday!', '예문 뜻': '생일 축하해!.'}, {'단어': 'card', '단어 뜻': '카드', '품사': '', '예문': 'Here is my card.', '예문 뜻': '여기 내 카드야.'}, {'단어': 'drum', '단어 뜻': '북', '품사': '', '예문': 'Let’s play the drum.', '예문 뜻': '드럼을 치자.'}, {'단어': 'gift', '단어 뜻': '선물', '품사': '', '예문': 'Here is my gift.', '예문 뜻': '여기 내 선물이야.'}, {'단어': 'guitar', '단어 뜻': '기타', '품사': '', '예문': 'Let’s play the guitar.', '예문 뜻': '기타를 치자.'}, {'단어': 'party', '단어 뜻': '파티', '품사': '', '예문': 'Let’s have a party.', '예문 뜻': '파티를 열자'}, {'단어': 'piano', '단어 뜻': '피아노', '품사': '', '예문': 'Let’s play the piano.', '예문 뜻': '피아노를 치자.'}, {'단어': 'recorder', '단어 뜻': '피리', '품사': '', '예문': 'Let’s play the recorder.', '예문 뜻': '피리를 불자'}, {'단어': 'song', '단어 뜻': '노래', '품사': '', '예문': 'Let’s sing a song.', '예문 뜻': '노래를 부르자.'}, {'단어': 'violin', '단어 뜻': '바이올린', '품사': '', '예문': 'Let’s play the violin.', '예문 뜻': '바이올린을 켜자.'}]
# Parsed data for ./pdf_words/start.pdf page 12: [{'단어': 'hot', '단어 뜻': '더운', '품사': '', '예문': 'It’s hot.', '예문 뜻': '더워.'}, {'단어': 'cold', '단어 뜻': '추운', '품사': '', '예문': 'It’s cold.', '예문 뜻': '추워.'}, {'단어': 'fast', '단어 뜻': '빠른', '품사': '', '예문': 'It’s fast.', '예문 뜻': '그것은 빨라.'}, {'단어': 'slow', '단어 뜻': '느린', '품사': '', '예문': 'The turtle is slow.', '예문 뜻': '그 거북이는 느려.'}, {'단어': 'clean', '단어 뜻': '깨끗한', '품사': '', '예문': 'It’s clean.', '예문 뜻': '그것은 깨끗해.'}, {'단어': 'dirty', '단어 뜻': '더러운', '품사': '', '예문': 'The table is dirty.', '예문 뜻': '그 탁자는 더러워.'}, {'단어': 'early', '단어 뜻': '일찍', '품사': '', '예문': 'I get up early.', '예문 뜻': '나는 일찍 일어나.'}, {'단어': 'late', '단어 뜻': '늦은', '품사': '', '예문': 'I get up late.', '예문 뜻': '나는 늦게 일어나.'}, {'단어': 'quiet', '단어 뜻': '조용한', '품사': '', '예문': 'They are quiet.', '예문 뜻': '그들은 조용해.'}, {'단어': 'noisy', '단어 뜻': '시끄러운', '품사': '', '예문': 'They are noisy.', '예문 뜻': '그들은 시끄러워.'}, {'단어': 'bank', '단어 뜻': '은행', '품사': '', '예문': 'We go to the bank.', '예문 뜻': '우리는 은행에 가.'}, {'단어': 'bookstore', '단어 뜻': '서점', '품사': '', '예문': 'We’re in the bookstore.', '예문 뜻': '우리는 서점에 있어.'}, {'단어': 'hospital', '단어 뜻': '병원', '품사': '', '예문': 'I go to the hospital.', '예문 뜻': '나는 병원에 가.'}, {'단어': 'library', '단어 뜻': '도서관', '품사': '', '예문': 'I’m in the library.', '예문 뜻': '나는 도서관에 있어.'}, {'단어': 'museum', '단어 뜻': '박물관', '품사': '', '예문': 'We go to the museum.', '예문 뜻': '우리는 박물관에 가.'}, {'단어': 'park', '단어 뜻': '공원', '품사': '', '예문': 'I go to the park.', '예문 뜻': '나는 공원에 가.'}, {'단어': 'playground', '단어 뜻': '운동장', '품사': '', '예문': 'We’re at the playground.', '예문 뜻': '우리는 운동장에 있어.'}, {'단어': 'pool', '단어 뜻': '수영장', '품사': '', '예문': 'I’m at the pool.', '예문 뜻': '나는 수영장에 있어.'}, {'단어': 'school', '단어 뜻': '학교', '품사': '', '예문': 'I go to school.', '예문 뜻': '나는 학교에 가.'}, {'단어': 'zoo', '단어 뜻': '동물원', '품사': '', '예문': 'I’m at the zoo.', '예문 뜻': '나는 동물원에 있어.'}]
