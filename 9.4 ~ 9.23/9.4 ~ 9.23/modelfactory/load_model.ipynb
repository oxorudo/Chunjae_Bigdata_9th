# %%
from tensorflow import keras
import numpy as np
import os
import cv2

# %%
model = keras.models.load_model('./best_model3.keras')

# %%
model
# Out:
# <Sequential name=sequential_5, built=True>

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 이미지 경로 설정
dlist = './data/test/'
predict_list = [f for f in os.listdir(dlist) if f.lower().endswith(('jpg', 'jpeg', 'png', 'webp'))]  # 이미지 파일만 선택

# 실제 레이블 설정 (파일 이름에 따라 설정)
true_labels = []
for file_name in predict_list:
    if "human" in file_name or "사람" in file_name:  # 사람을 나타내는 파일명에 따라 레이블 설정
        true_labels.append(1)  # 사람 -> 1
    elif "horse" in file_name or "말" in file_name:  # 말을 나타내는 파일명에 따라 레이블 설정
        true_labels.append(0)  # 말 -> 0

print(f"레이블 개수: {len(true_labels)}, 이미지 파일 개수: {len(predict_list)}")

# 실제 레이블과 예측할 이미지 개수가 일치하는지 확인
assert len(true_labels) == len(predict_list), "레이블과 이미지 파일 개수가 일치하지 않습니다."

# 이미지 전처리
img = [cv2.imread(dlist + i) for i in predict_list]
img = [cv2.resize(i, (224, 224)) for i in img]  # 모델 입력 크기에 맞게 이미지 크기 조정
img = np.array(img)
img = img.astype('float32') / 255.0  # 정규화

# 모델 분류
cutoff = 0.5  # 분류 기준점
predictions = model.predict(img)  # 모델의 예측 값 반환

# 예측 레이블 및 혼동 행렬 생성용 데이터
predicted_labels = []
correct_count = 0
total_count = len(predictions)

for idx, prediction in enumerate(predictions):
    file_name = predict_list[idx]
    
    # 예측 확률 및 레이블 처리 (바이너리 분류)
    confidence = prediction[0]  # 이진 분류로 예측된 단일 확률 값을 사용
    predicted_label = 1 if confidence >= cutoff else 0  # cutoff에 따른 예측 레이블
    predicted_labels.append(predicted_label)  # 예측된 레이블 저장
    
    # 실제 레이블과 예측 레이블을 비교
    if predicted_label == true_labels[idx]:
        correct_count += 1  # 맞춘 경우 카운트 증가
    
    # 파일 이름과 확률 출력
    if predicted_label == 1:
        print(f"{file_name}: 사람, 확률: {confidence:.2f}")
    else:
        print(f"{file_name}: 말, 확률: {1 - confidence:.2f}")

# 전체 맞춘 비율 (정확도) 계산
accuracy = correct_count / total_count
print(f"\n전체 맞춘 비율(정확도): {accuracy * 100:.2f}%")

# 혼동 행렬 계산
cm = confusion_matrix(true_labels, predicted_labels)

# 혼동 행렬 시각화
plt.figure(figsize=(6.5, 6.5))  # 기본 크기의 1.3배
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False, square=True,
            xticklabels=['Horse', 'Human'], yticklabels=['Horse', 'Human'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 레이블 개수: 200, 이미지 파일 개수: 200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# human (31).jpg: 말, 확률: 0.58
# human (32).jpg: 말, 확률: 0.82
# human (33).jpg: 사람, 확률: 0.64
# human (34).jpg: 말, 확률: 0.70
# human (35).jpg: 사람, 확률: 0.90
# human (36).jpg: 사람, 확률: 0.65
# human (37).jpg: 말, 확률: 0.97
# human (38).jpg: 사람, 확률: 0.70
# human (39).jpg: 말, 확률: 0.89
# human (4).jpg: 말, 확률: 0.87
# human (4).png: 사람, 확률: 1.00
# human (40).jpg: 사람, 확률: 1.00
# human (41).jpg: 말, 확률: 0.90
# human (42).jpg: 말, 확률: 1.00
# human (43).jpg: 말, 확률: 0.83
# human (44).jpg: 사람, 확률: 1.00
# human (45).jpg: 사람, 확률: 0.98
# human (46).jpg: 사람, 확률: 0.96
# human (47).jpg: 말, 확률: 0.90
# human (48).jpg: 사람, 확률: 0.86
# human (49).jpg: 사람, 확률: 1.00
# human (5).jpg: 말, 확률: 0.87
# human (5).png: 사람, 확률: 0.98
# human (50).jpg: 말, 확률: 0.97
# human (51).jpg: 말, 확률: 0.63
# human (52).jpg: 사람, 확률: 0.57
# human (53).jpg: 사람, 확률: 0.96
# human (54).jpg: 말, 확률: 0.99
# human (55).jpg: 말, 확률: 0.66
# human (56).jpg: 사람, 확률: 0.90
# human (57).jpg: 말, 확률: 0.72
# human (58).jpg: 말, 확률: 0.98
# human (59).jpg: 사람, 확률: 0.94
# human (6).jpg: 사람, 확률: 0.99
# human (6).png: 사람, 확률: 0.98
# human (60).jpg: 사람, 확률: 0.84
# human (61).jpg: 사람, 확률: 0.69
# human (62).jpg: 말, 확률: 1.00
# human (63).jpg: 사람, 확률: 0.86
# human (64).jpg: 사람, 확률: 1.00
# human (65).jpg: 말, 확률: 0.52
# human (66).jpg: 말, 확률: 1.00
# human (67).jpg: 말, 확률: 0.86
# human (68).jpg: 말, 확률: 0.87
# human (69).jpg: 사람, 확률: 0.84
# human (7).jpg: 사람, 확률: 0.53
# human (7).png: 사람, 확률: 1.00
# human (70).jpg: 사람, 확률: 1.00
# human (71).jpg: 사람, 확률: 0.93
# human (72).jpg: 말, 확률: 0.98
# human (73).jpg: 사람, 확률: 0.50
# human (74).jpg: 말, 확률: 0.99
# human (75).jpg: 사람, 확률: 0.97
# human (76).jpg: 사람, 확률: 1.00
# human (77).jpg: 사람, 확률: 0.91
# human (78).jpg: 말, 확률: 0.97
# human (79).jpg: 사람, 확률: 0.90
# human (8).jpg: 말, 확률: 0.92
# human (8).png: 사람, 확률: 0.98
# human (80).jpg: 사람, 확률: 0.63
# human (81).jpg: 말, 확률: 0.99
# human (82).jpg: 말, 확률: 0.91
# human (9).jpg: 사람, 확률: 0.68
# human (9).png: 사람, 확률: 1.00
#
# 전체 맞춘 비율(정확도): 75.00%
